# %% [markdown]
# # Overview
#
# This notebook uses pyapacheatlas to inject lineage between input and output assets

# %%
pip install pyapacheatlas
# Out:
# Requirement already satisfied: pyapacheatlas in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (0.16.0)
# Requirement already satisfied: openpyxl>=3.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from pyapacheatlas) (3.1.5)
# Requirement already satisfied: requests>=2.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from pyapacheatlas) (2.32.3)
# Requirement already satisfied: et-xmlfile in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from openpyxl>=3.0->pyapacheatlas) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pyapacheatlas) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pyapacheatlas) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pyapacheatlas) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pyapacheatlas) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install snowflake-connector-python
# Out:
# Requirement already satisfied: snowflake-connector-python[pandas] in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (3.12.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (42.0.8)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (24.2.1)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (2.8.0)
# Requirement already satisfied: pytz in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (2024.1)
# Requirement already satisfied: requests<3.0.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (2.32.3)
# Requirement already satisfied: packaging in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from snowflake-connector-python[pandas]) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (2024.7.4)
# Requirement already satisfied: typing-extensions<5,>=4.3 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (4.12.2)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (3.15.4)
# Requirement already satisfied: sortedcontainers>=2.4.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from snowflake-connector-python[pandas]) (4.2.2)
# Requirement already satisfied: tomlkit in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (0.13.0)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (2.2.2)
# Requirement already satisfied: pyarrow in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python[pandas]) (17.0.0)
# Requirement already satisfied: pycparser in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python[pandas]) (2.22)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]) (2024.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0->snowflake-connector-python[pandas]) (2.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.0.0->snowflake-connector-python[pandas]) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "snowflake-connector-python[pandas]"
# Out:
# Collecting snowflake-connector-python
#   Downloading snowflake_connector_python-3.12.0-cp312-cp312-win_amd64.whl.metadata (65 kB)
#      ---------------------------------------- 0.0/65.6 kB ? eta -:--:--
#      ---------------------------------------- 65.6/65.6 kB 3.5 MB/s eta 0:00:00
# Collecting asn1crypto<2.0.0,>0.24.0 (from snowflake-connector-python)
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python) (1.16.0)
# Collecting cryptography<43.0.0,>=3.1.0 (from snowflake-connector-python)
#   Downloading cryptography-42.0.8-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting pyOpenSSL<25.0.0,>=16.2.0 (from snowflake-connector-python)
#   Downloading pyOpenSSL-24.2.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python) (2.8.0)
# Collecting pytz (from snowflake-connector-python)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: requests<3.0.0 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: packaging in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from snowflake-connector-python) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python) (2024.7.4)
# Requirement already satisfied: typing-extensions<5,>=4.3 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from snowflake-connector-python) (4.12.2)
# Collecting filelock<4,>=3.5 (from snowflake-connector-python)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting sortedcontainers>=2.4.0 (from snowflake-connector-python)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from snowflake-connector-python) (4.2.2)
# Collecting tomlkit (from snowflake-connector-python)
#   Downloading tomlkit-0.13.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pycparser in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0->snowflake-connector-python) (2.2.2)
# Downloading snowflake_connector_python-3.12.0-cp312-cp312-win_amd64.whl (913 kB)
#    ---------------------------------------- 0.0/913.3 kB ? eta -:--:--
#    -------------------------- ------------ 614.4/913.3 kB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 913.3/913.3 kB 9.6 MB/s eta 0:00:00
# Downloading asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.0 kB ? eta -:--:--
#    ---------------------------------------- 105.0/105.0 kB 5.9 MB/s eta 0:00:00
# Downloading cryptography-42.0.8-cp39-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.6/2.9 MB 17.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.8/2.9 MB 13.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.2/2.9 MB 9.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.7/2.9 MB 9.8 MB/s eta 0:00:01
#    ------------------------------ --------- 2.2/2.9 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.8/2.9 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 9.7 MB/s eta 0:00:00
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading pyOpenSSL-24.2.1-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.4 kB ? eta -:--:--
#    ---------------------------------------- 58.4/58.4 kB 3.2 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------- 505.5/505.5 kB 15.5 MB/s eta 0:00:00
# Downloading tomlkit-0.13.0-py3-none-any.whl (37 kB)
# Installing collected packages: sortedcontainers, pytz, asn1crypto, tomlkit, filelock, cryptography, pyOpenSSL, snowflake-connector-python
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.0
#     Uninstalling cryptography-43.0.0:
#       Successfully uninstalled cryptography-43.0.0
# Successfully installed asn1crypto-1.5.1 cryptography-42.0.8 filelock-3.15.4 pyOpenSSL-24.2.1 pytz-2024.1 snowflake-connector-python-3.12.0 sortedcontainers-2.4.0 tomlkit-0.13.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.0.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pidoudet\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\pidoudet\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.4/11.5 MB 18.0 MB/s eta 0:00:01
#    -------- ------------------------------- 2.3/11.5 MB 12.4 MB/s eta 0:00:01
#    --------- ------------------------------ 2.8/11.5 MB 10.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.3/11.5 MB 10.0 MB/s eta 0:00:01
#    ------------- -------------------------- 4.0/11.5 MB 9.7 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.5 MB 8.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.9/11.5 MB 8.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.5 MB 8.0 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.5 MB 7.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.5 MB 7.4 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.5 MB 7.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.1/11.5 MB 8.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.5 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 8.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.5 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.5 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 8.5 MB/s eta 0:00:00
# Downloading numpy-2.0.1-cp312-cp312-win_amd64.whl (16.3 MB)
#    ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.3 MB 15.4 MB/s eta 0:00:02
#    --- ------------------------------------ 1.3/16.3 MB 16.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.2/16.3 MB 17.8 MB/s eta 0:00:01
#    ------- -------------------------------- 3.1/16.3 MB 18.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.4/16.3 MB 18.8 MB/s eta 0:00:01
#    ------------- -------------------------- 5.4/16.3 MB 19.0 MB/s eta 0:00:01
#    --------------- ------------------------ 6.2/16.3 MB 17.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.9/16.3 MB 16.9 MB/s eta 0:00:01
#    ------------------- -------------------- 7.8/16.3 MB 17.2 MB/s eta 0:00:01
#    --------------------- ------------------ 8.9/16.3 MB 17.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.5/16.3 MB 16.8 MB/s eta 0:00:01
#    ------------------------- -------------- 10.3/16.3 MB 16.8 MB/s eta 0:00:01
#    --------------------------- ------------ 11.0/16.3 MB 16.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.6/16.3 MB 16.4 MB/s eta 0:00:01
#    ------------------------------ --------- 12.3/16.3 MB 15.6 MB/s eta 0:00:01
#    -------------------------------- ------- 13.1/16.3 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.9/16.3 MB 15.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.4/16.3 MB 15.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.1/16.3 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  15.9/16.3 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.3 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.3/16.3 MB 13.3 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    ---------------------------------------- 345.4/345.4 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.0.1 pandas-2.2.2 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Install Atlas Python client (https://github.com/wjohnson/pyapacheatlas)
import pyapacheatlas
import json
import snowflake.connector
import pandas as pd
import uuid

from pyapacheatlas.core import AtlasEntity
from pyapacheatlas.core import AtlasProcess
from pyapacheatlas.auth import ServicePrincipalAuthentication
from pyapacheatlas.core import PurviewClient
from pyapacheatlas.core.collections import PurviewCollectionsClient
from pyapacheatlas.core.typedef import EntityTypeDef, AtlasAttributeDef
from pyapacheatlas.core.util import GuidTracker

# %%
import pandas as mc
import importlib

importlib.reload(mc)
# Out:
# <module 'pandas' from 'c:\\Users\\pidoudet\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
# Define variable

# SPN + Purview account
vTenantID = ""
vClientID = ""
vClientSecret = ""
vPurviewAccount = "pdedemopurv"

#Snowflake information
vUser=""
vPassword=""
vAccount= ""
vWarehouse="COMPUTE_WH"
vDatabase="TASTY_BYTES_SAMPLE_DATA"
vSchema="RAW_POS"

# %%
# enter your service principal credentials here
oauth = ServicePrincipalAuthentication(
    tenant_id= vTenantID,
    client_id=vClientID,
    client_secret=vClientSecret
)


conn = snowflake.connector.connect(
    user=vUser,
    password=vPassword,
    account=vAccount,
    warehouse=vWarehouse,
    database=vDatabase,
    schema=vSchema
    )

# Instantiate PurviewClient, enter your Purview account name here
client = PurviewClient(
    account_name =  vPurviewAccount,
    authentication=oauth
)

collection = PurviewCollectionsClient(
    endpoint_url =  "https://" + vPurviewAccount +".purview.azure.com/",
    authentication=oauth
)

# %%
#client.get_all_typedefs()
# Out:
# {'enumDefs': [{'category': 'ENUM',
#    'guid': '6e30d01e-f5d0-9799-08e7-09b4f276c09c',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'glossary_term_status_value',
#    'description': 'glossary_term_status_value',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Approved', 'ordinal': 0},
#     {'value': 'Alert', 'ordinal': 1},
#     {'value': 'Expired', 'ordinal': 2},
#     {'value': 'Draft', 'ordinal': 3}]},
#   {'category': 'ENUM',
#    'guid': '42185ddb-29be-e911-ea52-890154eb07c0',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243475,
#    'updateTime': 1725387243475,
#    'version': 2,
#    'name': 'AtlasGlossaryTermRelationshipStatus',
#    'description': 'TermRelationshipStatus defines how reliable the relationship is between two glossary terms',
#    'typeVersion': '1.1',
#    'serviceType': 'atlas_core',
#    'lastModifiedTS': '2',
#    'elementDefs': [{'value': 'DRAFT',
#      'description': 'DRAFT means the relationship is under development.',
#      'ordinal': 0},
#     {'value': 'ACTIVE',
#      'description': 'ACTIVE means the relationship is validated and in use.',
#      'ordinal': 1},
#     {'value': 'DEPRECATED',
#      'description': 'DEPRECATED means the the relationship is being phased out.',
#      'ordinal': 2},
#     {'value': 'OBSOLETE',
#      'description': 'OBSOLETE means that the relationship should not be used anymore.',
#      'ordinal': 3},
#     {'value': 'OTHER',
#      'description': 'OTHER means that there is another status.',
#      'ordinal': 99}]},
#   {'category': 'ENUM',
#    'guid': 'ef90949b-3711-9a46-ba1e-5137abfe2b26',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243482,
#    'updateTime': 1725387243482,
#    'version': 1,
#    'name': 'ads_snapshot_status',
#    'description': 'ads_snapshot_status',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Succeeded', 'ordinal': 0},
#     {'value': 'Failed', 'ordinal': 1},
#     {'value': 'Cancelled', 'ordinal': 1}]},
#   {'category': 'ENUM',
#    'guid': 'a8681e87-f59c-78e0-7fc1-9c0bcc4553f7',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 2,
#    'name': 'file_action',
#    'description': 'file_action',
#    'typeVersion': '1.1',
#    'serviceType': 'file_system',
#    'lastModifiedTS': '2',
#    'elementDefs': [{'value': 'NONE', 'ordinal': 0},
#     {'value': 'EXECUTE', 'ordinal': 1},
#     {'value': 'WRITE', 'ordinal': 2},
#     {'value': 'WRITE_EXECUTE', 'ordinal': 3},
#     {'value': 'READ', 'ordinal': 4},
#     {'value': 'READ_EXECUTE', 'ordinal': 5},
#     {'value': 'READ_WRITE', 'ordinal': 6},
#     {'value': 'ALL', 'ordinal': 7}]},
#   {'category': 'ENUM',
#    'guid': '01c06479-0a58-5bcb-836e-d015d1d46949',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'Purview_System_Status',
#    'description': 'Purview_System_Status',
#    'typeVersion': '1.0',
#    'serviceType': 'Purview Business',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Planned', 'ordinal': 0},
#     {'value': 'Under Development', 'ordinal': 1},
#     {'value': 'Implemented', 'ordinal': 2},
#     {'value': 'Retired', 'ordinal': 3},
#     {'value': 'Decommissioned', 'ordinal': 4}]},
#   {'category': 'ENUM',
#    'guid': '72dfd414-9264-743f-d3a8-1d56b9ecf2ab',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243485,
#    'updateTime': 1725387243485,
#    'version': 1,
#    'name': 'ml_model_deployment_status',
#    'description': 'The deployment status of a ML model build',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'unknown', 'ordinal': 0},
#     {'value': 'deploying', 'ordinal': 1},
#     {'value': 'deployed', 'ordinal': 2},
#     {'value': 'stopping', 'ordinal': 3},
#     {'value': 'stopped', 'ordinal': 4}]},
#   {'category': 'ENUM',
#    'guid': '1336ee25-b0ed-bad3-a84a-3a26b3811215',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'Purview_BusinessProcess_Status',
#    'description': 'Purview_BusinessProcess_Status',
#    'typeVersion': '1.0',
#    'serviceType': 'Purview Business',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Candidate', 'ordinal': 0},
#     {'value': 'Accepted', 'ordinal': 1},
#     {'value': 'Standardized', 'ordinal': 2},
#     {'value': 'Deprecated', 'ordinal': 3}]},
#   {'category': 'ENUM',
#    'guid': '494eb577-0c4e-b781-4c8e-e6a7e3b5f404',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243481,
#    'updateTime': 1725387243481,
#    'version': 1,
#    'name': 'cosmosdb_account_api',
#    'description': 'cosmosdb_account_api',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Cosmos DB',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'SQL', 'ordinal': 0},
#     {'value': 'MongoDb', 'ordinal': 1},
#     {'value': 'Cassandra', 'ordinal': 2},
#     {'value': 'Table', 'ordinal': 3},
#     {'value': 'Gremlin', 'ordinal': 4}]},
#   {'category': 'ENUM',
#    'guid': 'b9aaf55f-2689-8680-cad4-7bea87aa51f2',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243475,
#    'updateTime': 1725387243475,
#    'version': 2,
#    'name': 'AtlasGlossaryTermAssignmentStatus',
#    'description': 'TermAssignmentStatus defines how much the semantic assignment should be trusted.',
#    'typeVersion': '1.1',
#    'serviceType': 'atlas_core',
#    'lastModifiedTS': '2',
#    'elementDefs': [{'value': 'DISCOVERED',
#      'description': 'DISCOVERED means that the semantic assignment was added by a discovery engine.',
#      'ordinal': 0},
#     {'value': 'PROPOSED',
#      'description': 'PROPOSED means that the semantic assignment was proposed by person - they may be a subject matter expert, or consumer of the Referenceable asset',
#      'ordinal': 1},
#     {'value': 'IMPORTED',
#      'description': 'IMPORTED means that the semantic assignment has been imported from outside of the open metadata cluster',
#      'ordinal': 2},
#     {'value': 'VALIDATED',
#      'description': 'VALIDATED means that the semantic assignment has been reviewed and is highly trusted.',
#      'ordinal': 3},
#     {'value': 'DEPRECATED',
#      'description': 'DEPRECATED means that the semantic assignment is being phased out. There may be another semantic assignment to the Referenceable that will ultimately replace this one.',
#      'ordinal': 4},
#     {'value': 'OBSOLETE',
#      'description': 'OBSOLETE means that the semantic assignment is no longer in use,',
#      'ordinal': 5},
#     {'value': 'OTHER',
#      'description': 'OTHER means that the semantic assignment value does not match any of the other Term Assignment Status values',
#      'ordinal': 6}]},
#   {'category': 'ENUM',
#    'guid': '4b4da334-9a23-710b-5696-baf75c3af633',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_machine_learning_account_type',
#    'description': 'azure_machine_learning_account_type',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Machine Learning Service',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Workspace', 'ordinal': 0},
#     {'value': 'Registry', 'ordinal': 1}]},
#   {'category': 'ENUM',
#    'guid': 'bb326328-3a0c-46f6-8d43-2d96abc35cc4',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 2,
#    'name': 'hive_principal_type',
#    'description': 'hive_principal_type',
#    'typeVersion': '1.1',
#    'serviceType': 'hive',
#    'lastModifiedTS': '2',
#    'elementDefs': [{'value': 'USER', 'ordinal': 1},
#     {'value': 'ROLE', 'ordinal': 2},
#     {'value': 'GROUP', 'ordinal': 3}]},
#   {'category': 'ENUM',
#    'guid': '40fb8184-5cb3-1cd5-8633-dfefec42caee',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 1,
#    'name': 'Purview_Relationship_Type',
#    'description': 'Purview_Relationship_Type',
#    'typeVersion': '1.0',
#    'serviceType': 'Purview Core',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Has', 'ordinal': 0},
#     {'value': 'Manages', 'ordinal': 1},
#     {'value': 'Represents', 'ordinal': 2},
#     {'value': 'Groups', 'ordinal': 3},
#     {'value': 'Offers', 'ordinal': 4},
#     {'value': 'Implements', 'ordinal': 5}]},
#   {'category': 'ENUM',
#    'guid': '24fafa85-6344-c42c-ea38-1db696e65123',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243482,
#    'updateTime': 1725387243482,
#    'version': 1,
#    'name': 'ads_share_type',
#    'description': 'ads_share_type',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Snapshot', 'ordinal': 0},
#     {'value': 'InPlace', 'ordinal': 1}]},
#   {'category': 'ENUM',
#    'guid': 'f3a24724-e47f-7f77-339b-67153b6274bf',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243482,
#    'updateTime': 1725387243482,
#    'version': 1,
#    'name': 'ads_snapshot_type',
#    'description': 'ads_snapshot_type',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Incremental', 'ordinal': 0},
#     {'value': 'FullCopy', 'ordinal': 1}]},
#   {'category': 'ENUM',
#    'guid': 'd76d5174-7ea7-e3d3-a0c5-714bd9e1dc75',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243484,
#    'updateTime': 1725387243484,
#    'version': 1,
#    'name': 'ozone_replication_type',
#    'description': 'The replication type for an Ozone key',
#    'typeVersion': '1.0',
#    'serviceType': 'ozone',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'RATIS', 'ordinal': 0},
#     {'value': 'STAND_ALONE', 'ordinal': 1},
#     {'value': 'CHAINED', 'ordinal': 2}]},
#   {'category': 'ENUM',
#    'guid': '32f31348-5c77-5e27-1198-19c2cfc24499',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243485,
#    'updateTime': 1725387243485,
#    'version': 1,
#    'name': 'powerbi_endorsement_status',
#    'description': 'powerbi_endorsement_status',
#    'typeVersion': '1.0',
#    'serviceType': 'Fabric',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Promoted', 'ordinal': 0},
#     {'value': 'Certified', 'ordinal': 1}]},
#   {'category': 'ENUM',
#    'guid': 'a1bc3d6a-82f2-feaf-4fe8-545dbfa9132d',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'share_kind',
#    'description': 'share_kind',
#    'typeVersion': '1.0',
#    'serviceType': 'Share',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'InPlace', 'ordinal': 0}]},
#   {'category': 'ENUM',
#    'guid': 'c656f39b-a631-43f3-bed5-7f6ed845d125',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'share_storekind',
#    'description': 'share_storekind',
#    'typeVersion': '1.0',
#    'serviceType': 'Share',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'AzureBlobStorage', 'ordinal': 0},
#     {'value': 'AzureStorageDataLake', 'ordinal': 1}]},
#   {'category': 'ENUM',
#    'guid': 'dee83308-c3ed-6778-a62f-36f9a6877346',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243475,
#    'updateTime': 1725387243475,
#    'version': 1,
#    'name': 'atlas_operation',
#    'description': 'Defines audit operations in Atlas',
#    'typeVersion': '1.0',
#    'serviceType': 'atlas_core',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'OTHERS', 'ordinal': 0},
#     {'value': 'PURGE', 'ordinal': 1},
#     {'value': 'EXPORT', 'ordinal': 2},
#     {'value': 'IMPORT', 'ordinal': 3},
#     {'value': 'IMPORT_DELETE_REPL', 'ordinal': 4},
#     {'value': 'TYPE_DEF_CREATE', 'ordinal': 5},
#     {'value': 'TYPE_DEF_UPDATE', 'ordinal': 6},
#     {'value': 'TYPE_DEF_DELETE', 'ordinal': 7},
#     {'value': 'SERVER_START', 'ordinal': 8},
#     {'value': 'SERVER_STATE_ACTIVE', 'ordinal': 9}]},
#   {'category': 'ENUM',
#    'guid': 'fc65fc32-3596-56ea-f430-99f0cb71debd',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'storage_account_sku',
#    'description': 'storage_account_sku',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Standard_LRS', 'ordinal': 0},
#     {'value': 'Standard_GRS', 'ordinal': 1},
#     {'value': 'Standard_RAGRS', 'ordinal': 2},
#     {'value': 'Standard_ZRS', 'ordinal': 3},
#     {'value': 'Premium_LRS', 'ordinal': 4}]},
#   {'category': 'ENUM',
#    'guid': 'edce5d5f-699b-f36f-e4d8-8e18bb4b10f5',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'blob_access_tier',
#    'description': 'blob_access_tier',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Blob Storage',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Unknown', 'ordinal': 0},
#     {'value': 'Hot', 'ordinal': 1},
#     {'value': 'Cool', 'ordinal': 2},
#     {'value': 'Archive', 'ordinal': 3}]},
#   {'category': 'ENUM',
#    'guid': 'eb9f089d-d8b1-068d-bfbf-84bd267f5904',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'container_public_access_level',
#    'description': 'container_public_access_level',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Blob Storage',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Off', 'ordinal': 0},
#     {'value': 'Container', 'ordinal': 1},
#     {'value': 'Blob', 'ordinal': 2},
#     {'value': 'Unknown', 'ordinal': 3}]},
#   {'category': 'ENUM',
#    'guid': '171bba26-3a17-3f5c-50f2-1e313c87d473',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'blob_type',
#    'description': 'blob_type',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Blob Storage',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Unspecified', 'ordinal': 0},
#     {'value': 'PageBlob', 'ordinal': 1},
#     {'value': 'BlockBlob', 'ordinal': 2},
#     {'value': 'AppendBlob', 'ordinal': 3}]},
#   {'category': 'ENUM',
#    'guid': 'ad3d7a83-08c3-9717-1305-e18408e10308',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'storage_account_kind',
#    'description': 'storage_account_kind',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'StorageClassic', 'ordinal': 0},
#     {'value': 'StorageV2', 'ordinal': 1},
#     {'value': 'BlobStorage', 'ordinal': 2}]},
#   {'category': 'ENUM',
#    'guid': '39666d98-c34d-fa85-bfb8-5e35a2cadc68',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'share_state',
#    'description': 'share_state',
#    'typeVersion': '1.0',
#    'serviceType': 'Share',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Attached', 'ordinal': 0},
#     {'value': 'Detached', 'ordinal': 1}]},
#   {'category': 'ENUM',
#    'guid': '4087d1d7-70bc-bf1f-fc42-818b7e30fcbf',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243484,
#    'updateTime': 1725387243484,
#    'version': 1,
#    'name': 'ozone_storage_type',
#    'description': 'The storage type for an Ozone bucket',
#    'typeVersion': '1.0',
#    'serviceType': 'ozone',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'RAM_DISK', 'ordinal': 0},
#     {'value': 'SSD', 'ordinal': 1},
#     {'value': 'DISK', 'ordinal': 2},
#     {'value': 'ARCHIVE', 'ordinal': 3}]},
#   {'category': 'ENUM',
#    'guid': 'd100c837-68c7-283a-764e-ea86be31c0b4',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243486,
#    'updateTime': 1725387243486,
#    'version': 1,
#    'name': 'parquet_field_repetition_type',
#    'description': 'parquet_field_repetition_type',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'optional', 'ordinal': 0},
#     {'value': 'required', 'ordinal': 1},
#     {'value': 'repeated', 'ordinal': 2}]},
#   {'category': 'ENUM',
#    'guid': '45ba3844-8550-6ae7-8d32-132970c027d9',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 1,
#    'name': 'Purview_Relationship_Type_Reverse',
#    'description': 'Purview_Relationship_Type_Reverse',
#    'typeVersion': '1.0',
#    'serviceType': 'Purview Core',
#    'lastModifiedTS': '1',
#    'elementDefs': [{'value': 'Is Part Of', 'ordinal': 0},
#     {'value': 'Is Managed By', 'ordinal': 1},
#     {'value': 'Is Represented By', 'ordinal': 2},
#     {'value': 'Is Grouped By', 'ordinal': 3},
#     {'value': 'Is Offered By', 'ordinal': 4},
#     {'value': 'Is Implemented By', 'ordinal': 5}]}],
#  'structDefs': [{'category': 'STRUCT',
#    'guid': '9e2e9898-17e9-b378-47f9-c946b45bb595',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'blob_soft_deleted_state',
#    'description': 'blob_soft_deleted_state',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Blob Storage',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'deleted',
#      'typeName': 'boolean',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'deletedTime',
#      'typeName': 'date',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'remainingRetentionDays',
#      'typeName': 'long',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'ceff9c30-d69e-1ad5-de20-8b4d6478eb08',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_resourceuri',
#    'description': 'azure_synapse_resourceuri',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'resourceType',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'uri',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'f4318336-471c-e256-08f3-0c320b1a3eef',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 2,
#    'name': 'hive_order',
#    'description': 'hive_order',
#    'typeVersion': '1.1',
#    'serviceType': 'hive',
#    'lastModifiedTS': '2',
#    'attributeDefs': [{'name': 'order',
#      'typeName': 'int',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'col',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '0b796a85-5126-c26a-be3b-2d267fe0b5db',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_lake_distributioninfo',
#    'description': 'azure_synapse_lake_distributioninfo',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'type',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'keys',
#      'typeName': 'array<string>',
#      'isOptional': True,
#      'cardinality': 'LIST',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 2147483647,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'count',
#      'typeName': 'long',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'sortKeys',
#      'typeName': 'array<azure_synapse_sorting>',
#      'isOptional': True,
#      'cardinality': 'LIST',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 2147483647,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'f5e943b6-09dd-d672-a3a5-296546c5c163',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 2,
#    'name': 'fs_permissions',
#    'description': 'fs_permissions',
#    'typeVersion': '1.1',
#    'serviceType': 'file_system',
#    'lastModifiedTS': '2',
#    'attributeDefs': [{'name': 'group',
#      'typeName': 'file_action',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'user',
#      'typeName': 'file_action',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'sticky',
#      'typeName': 'boolean',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'others',
#      'typeName': 'file_action',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '5d77d1ed-ebda-7687-17c6-e4cd350f040b',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_storagedescriptor',
#    'description': 'azure_synapse_storagedescriptor',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'distributionInfo',
#      'typeName': 'azure_synapse_lake_distributioninfo',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'format',
#      'typeName': 'azure_synapse_formatinfo',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'source',
#      'typeName': 'azure_synapse_lake_datasource',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'properties',
#      'typeName': 'map<string,string>',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'compressed',
#      'typeName': 'boolean',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'serDeInfo',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'isStoredAsSubdirectories',
#      'typeName': 'boolean',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'fcd2963f-b042-e896-53d9-b310c33fd0a1',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'blob_delete_retention_policy',
#    'description': 'blob_delete_retention_policy',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Blob Storage',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'enabled',
#      'typeName': 'boolean',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'days',
#      'typeName': 'long',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '79eebd8a-3b6a-fd58-1500-1124ae928110',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_lake_datasource',
#    'description': 'azure_synapse_lake_datasource',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'provider',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'location',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'properties',
#      'typeName': 'map<string,string>',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '466ca55c-a910-be0d-bfeb-6f847c38eafb',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_columnrelationshipinformation',
#    'description': 'azure_synapse_columnrelationshipinformation',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'fromColumnName',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'toColumnName',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '9c35b8c1-aba7-4a71-419c-0e0c5b190ca2',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_formatinfo',
#    'description': 'azure_synapse_formatinfo',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'inputFormat',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'outputFormat',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'formatType',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'serDeName',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'serializeLib',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '13cf8a9d-1432-161c-cde5-ae346ca28381',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_lake_database_tablepartitioning',
#    'description': 'azure_synapse_lake_database_tablepartitioning',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'keys',
#      'typeName': 'array<string>',
#      'isOptional': True,
#      'cardinality': 'LIST',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 2147483647,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'partitionFunctionType',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '7092dce7-bfa8-4da3-5bd1-f58b5d239398',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_typeinfo',
#    'description': 'azure_synapse_typeinfo',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'typeFamily',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'typeName',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'isTableType',
#      'typeName': 'boolean',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'isComplexType',
#      'typeName': 'boolean',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'isNullable',
#      'typeName': 'boolean',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'length',
#      'typeName': 'int',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'precision',
#      'typeName': 'int',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'scale',
#      'typeName': 'int',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'collation',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'properties',
#      'typeName': 'map<string,string>',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'e48b74f3-9df8-5d16-2a96-5814a112d91c',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 2,
#    'name': 'aws_tag',
#    'description': 'Atlas Type representing a tag/value pair associated with an AWS object, eg S3 bucket',
#    'typeVersion': '1.1',
#    'serviceType': 'aws',
#    'lastModifiedTS': '2',
#    'attributeDefs': [{'name': 'key',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'value',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'c46b9bfe-aa33-bd98-1ab1-12534b4a4308',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 2,
#    'name': 'aws_cloud_watch_metric',
#    'description': 'Atlas Type representing a metric provided by AWS Cloud Watch',
#    'typeVersion': '1.1',
#    'serviceType': 'aws',
#    'lastModifiedTS': '2',
#    'attributeDefs': [{'name': 'metricName',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'scope',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'bc6e7dba-2f7d-c81f-92a9-bc4444cc4a31',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243484,
#    'updateTime': 1725387243484,
#    'version': 1,
#    'name': 'ozone_key_location',
#    'description': 'Location information about Ozone key',
#    'typeVersion': '1.0',
#    'serviceType': 'ozone',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'containerID',
#      'typeName': 'long',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'localID',
#      'typeName': 'long',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'length',
#      'typeName': 'long',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'offset',
#      'typeName': 'long',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '7eca7b30-b5a5-da54-bcc0-83e4fea11046',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243481,
#    'updateTime': 1725387243481,
#    'version': 2,
#    'name': 'aws_s3_access_policy',
#    'description': 'Atlas Type representing an access policy statement on an S3 bucket. Can later be fleshed out to represent the JSON structure of the statement.',
#    'typeVersion': '1.1',
#    'serviceType': 'aws',
#    'lastModifiedTS': '2',
#    'attributeDefs': [{'name': 'policyString',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'd5e52013-f7a4-db1b-682c-08a7a07f0ffe',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243481,
#    'updateTime': 1725387243481,
#    'version': 1,
#    'name': 'cosmosdb_timetolive',
#    'description': 'cosmosdb_timetolive',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Cosmos DB',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'isOn',
#      'typeName': 'boolean',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'defaultValue',
#      'typeName': 'long',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'fd5e2b6a-6b2f-db01-ae48-0ad67f1efc6e',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 2,
#    'name': 'hive_serde',
#    'description': 'hive_serde',
#    'typeVersion': '1.1',
#    'serviceType': 'hive',
#    'lastModifiedTS': '2',
#    'attributeDefs': [{'name': 'name',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'serializationLib',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'parameters',
#      'typeName': 'map<string,string>',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '8c02797d-fa17-857e-329f-8d47b5270fe8',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243481,
#    'updateTime': 1725387243481,
#    'version': 2,
#    'name': 'aws_s3_bucket_lifeCycleRule',
#    'description': 'Atlas Type representing the life cycle rules for S3 object store bucket',
#    'typeVersion': '1.1',
#    'serviceType': 'aws',
#    'lastModifiedTS': '2',
#    'attributeDefs': [{'name': 'ruleType',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'days',
#      'typeName': 'int',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'storageClass',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': 'd96ff541-abd9-a199-58b6-2deb81e4ca5f',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243481,
#    'updateTime': 1725387243481,
#    'version': 1,
#    'name': 'cosmosdb_offer',
#    'description': 'cosmosdb_offer',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Cosmos DB',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'content',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False},
#     {'name': 'offerLink',
#      'typeName': 'string',
#      'isOptional': False,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 1,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False}]},
#   {'category': 'STRUCT',
#    'guid': '44b50a15-6583-f7c7-e924-de0cf22657c5',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243483,
#    'updateTime': 1725387243483,
#    'version': 1,
#    'name': 'azure_synapse_sorting',
#    'description': 'azure_synapse_sorting',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure Synapse Analytics',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'keyName',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False},
#     {'name': 'sortOrder',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}]}],
#  'classificationDefs': [{'category': 'CLASSIFICATION',
#    'guid': '40e64bd9-55f3-4a09-9bd6-1db18dced9dd',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.GOVERNMENT.CYPRUS.TAX.IDENTIFICATION.NUMBER',
#    'description': 'Cyprus Tax Identification Number',
#    'typeVersion': '1.0',
#    'attributeDefs': [],
#    'superTypes': ['MICROSOFT.BASE.CLASSIFICATION'],
#    'subTypes': [],
#    'entityTypes': [],
#    'searchable': False,
#    'options': {'displayName': 'Cyprus Tax Identification Number'}},
#   {'category': 'CLASSIFICATION',
#    'guid': '4e979794-49a0-407e-a0b9-2c536937b925',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.GOVERNMENT.CHILE.CDI_NUMBER',
#    'description': 'Chile Identity Card Number',
#    'typeVersion': '1.0',
#    'attributeDefs': [],
#    'superTypes': ['MICROSOFT.BASE.CLASSIFICATION'],
#    'subTypes': [],
#    'entityTypes': [],
#    'searchable': False,
#    'options': {'displayName': 'Chile Identity Card Number'}},
#   {'category': 'CLASSIFICATION',
#    'guid': 'a3bdaa4a-8371-4735-8fa5-56ee0fb4afc4',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.GOVERNMENT.MALTA.DRIVERS.LICENSE.NUMBER',
#    'description': "Malta Driver's License Number",
#    'typeVersion': '1.0',
#    'attributeDefs': [],
#    'superTypes': ['MICROSOFT.BASE.CLASSIFICATION'],
#    'subTypes': [],
#    'entityTypes': [],
#    'searchable': False,
#    'options': {'displayName': "Malta Driver's License Number"}},
#   {'category': 'CLASSIFICATION',
#    'guid': 'fb621f20-3876-4cfc-acec-8c8e73ca32c7',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.GOVERNMENT.TURKEY.TURKISH_NATIONAL_IDENTIFICATION_NUMBER',
#    'description': 'Turkish National Identity',
#    'typeVersion': '1.0',
#    'attributeDefs': [],
#    'superTypes': ['MICROSOFT.BASE.CLASSIFICATION'],
#    'subTypes': [],
#    'entityTypes': [],
#    'searchable': False,
#    'options': {'displayName': 'Turkish National Identity'}},
#   {'category': 'CLASSIFICATION',
#    'guid': 'E3AAF206-4297-412F-9E06-BA8487E22456',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.GOVERNMENT.POLAND.PESEL_NUMBER',
#    'description': 'Poland National ID (PESEL)',
#    'typeVersion': '1.0',
#    'attributeDefs': [],
#    'superTypes': ['MICROSOFT.BASE.CLASSIFICATION'],
#    'subTypes': [],
#    'entityTypes': [],
#    'searchable': False,
#    'options': {'displayName': 'Poland National ID (PESEL)'}},
#   {'category': 'CLASSIFICATION',
#    'guid': '86f7628b-e0f4-4dc3-9fbc-e4300e4c7d78',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.GOVERNMENT.LITHUANIA.DRIVERS.LICENSE.NUMBER',
#    'description': "Lithuania Driver's License Number",
#    'typeVersion': '1.0',
#    'attributeDefs': [],
#    'superTypes': ['MICROSOFT.BASE.CLASSIFICATION'],
#    'subTypes': [],
#    'entityTypes': [],
#    'searchable': False,
#    'options': {'displayName': "Lithuania Driver's License Number"}},
#   {'category': 'CLASSIFICATION',
#    'guid': '50842eb7-edc8-4019-85dd-5a5c1f2bb085',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.FINANCIAL.CREDIT_CARD_NUMBER',
#    'description': 'Credit Card Number',
#    'typeVersion': '1.0',
#    'attributeDefs': [],
#    'superTypes': ['MICROSOFT.BASE.CLASSIFICATION'],
#    'subTypes': [],
#    'entityTypes': [],
#    'searchable': False,
#    'options': {'displayName': 'Credit Card Number'}},
#   {'category': 'CLASSIFICATION',
#    'guid': 'f71ff7dd-dad6-7e67-cd31-a88460ea99bb',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243476,
#    'updateTime': 1725387243476,
#    'version': 1,
#    'name': 'MICROSOFT.BASE.CLASSIFICATION',
#    'description': 'Purview base classification class with common attributes',
#    'typeVersion': '1.0',
#    'attributeDefs': [{'name': 'confidence',
#      'typeName': 'float',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': False,
#      'includeInNotification': False}],
#    'superTypes': [],
#    'subTypes': ['MICROSOFT.GOVERNMENT.CHILE.CDI_NUMBER',
#     'MICROSOFT.GOVERNMENT.CYPRUS.TAX.IDENTIFICATION.NUMBER',
#     'MICROSOFT.GOVERNMENT.TURKEY.TURKISH_NATIONAL_IDENTIFICATION_NUMBER',
#     'MICROSOFT.GOVERNMENT.MALTA.DRIVERS.LICENSE.NUMBER',
#     'MICROSOFT.GOVERNMENT.POLAND.PESEL_NUMBER',
#     'MICROSOFT.GOVERNMENT.LITHUANIA.DRIVERS.LICENSE.NUMBER',
#     'MICROSOFT.FINANCIAL.CREDIT_CARD_NUMBER',
#     'MICROSOFT.FINANCIAL.ISRAEL.BANK_ACCOUNT_NUMBER',
#     'MICROSOFT.FINANCIAL.AUSTRALIA.BANK_ACCOUNT_NUMBER',
#     'MICROSOFT.PERSONAL.DATE_OF_BIRTH',
#     'MICROSOFT.GOVERNMENT.SPAIN.DNI',
#     'MICROSOFT.GOVERNMENT.JAPAN.SOCIAL_INSURANCE_NUMBER',
#     'MICROSOFT.GOVERNMENT.US.ZIP_CODE',
#     'MICROSOFT.SECURITY.COMMON_PASSWORDS',
#     'MICROSOFT.GOVERNMENT.GERMANY.PASSPORT_NUMBER',
#     'MICROSOFT.PERSONAL.ETHNIC_GROUP',
#     'MICROSOFT.GOVERNMENT.SWEDEN.PASSPORT_NUMBER',
#     'MICROSOFT.GOVERNMENT.TAIWAN.RESIDENT_CERTIFICATE',
#     'MICROSOFT.GOVERNMENT.POLAND.DRIVERS.LICENSE.NUMBER',
#     'MICROSOFT.GOVERNMENT.POLAND.PASSPORT_NUMBER',
# ...
#    'description': 'hive_table_ddl_queries',
#    'typeVersion': '1.0',
#    'serviceType': 'hive',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'hive_table',
#     'name': 'ddlQueries',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'hive_table_ddl',
#     'name': 'table',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '665f2178-af59-7cda-09a3-1ddd12671a4f',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243486,
#    'updateTime': 1725387243486,
#    'version': 1,
#    'name': 'sap_ecc_package_views',
#    'description': 'sap_ecc_package_views',
#    'typeVersion': '1.0',
#    'serviceType': 'SAP ECC',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'sap_ecc_package',
#     'name': 'views',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'sap_ecc_view',
#     'name': 'package',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '6d0fe136-f3bf-6985-e60e-c4ae9fe139b1',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243487,
#    'updateTime': 1725387243487,
#    'version': 1,
#    'name': 'sap_bw_advanced_data_store_object_primary_key_fields',
#    'description': 'sap_bw_advanced_data_store_object_primary_key_fields',
#    'typeVersion': '1.0',
#    'serviceType': 'SAP BW',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'ASSOCIATION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'sap_bw_advanced_data_store_object',
#     'name': 'primary_key_fields',
#     'isContainer': False,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'sap_bw_info_object_attribute',
#     'name': 'advanced_data_store_object',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': 'edf838fe-3475-2fd0-cb4f-bbc8b76f1234',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'db2_foreign_key_unique_constraints',
#    'description': 'db2_foreign_key_unique_constraints',
#    'typeVersion': '1.0',
#    'serviceType': 'DB2',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'ASSOCIATION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'db2_foreign_key',
#     'name': 'unique_constraints',
#     'isContainer': False,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'db2_unique_constraint',
#     'name': 'foreign_keys',
#     'isContainer': False,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '159ca0f4-24d8-b3db-be79-47b4c8508910',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243478,
#    'updateTime': 1725387243478,
#    'version': 1,
#    'name': 'openlineage_operation_job',
#    'description': 'openlineage_operation_job',
#    'typeVersion': '1.0',
#    'serviceType': 'OpenLineage',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'openlineage_run_operation',
#     'name': 'job',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'openlineage_job',
#     'name': 'operations',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '260f288f-210b-432a-4038-0a621dbb8638',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243488,
#    'updateTime': 1725387243488,
#    'version': 1,
#    'name': 'erwin_schema_sequences',
#    'description': 'erwin_schema_sequences',
#    'typeVersion': '1.0',
#    'serviceType': 'Erwin',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'ASSOCIATION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'erwin_schema',
#     'name': 'sequences',
#     'isContainer': False,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'erwin_sequence',
#     'name': 'erwinschema',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': 'b7468e3a-ffd3-c3ed-0da0-a8ca69d163b2',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243486,
#    'updateTime': 1725387243486,
#    'version': 1,
#    'name': 'sap_s4hana_function_group_function_modules',
#    'description': 'sap_s4hana_function_group_function_modules',
#    'typeVersion': '1.0',
#    'serviceType': 'SAP S4HANA',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'sap_s4hana_function_group',
#     'name': 'function_modules',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'sap_s4hana_function_module',
#     'name': 'function_group',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': 'bc95850b-89b6-cc0a-b2fd-5cbfa5a2c808',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243481,
#    'updateTime': 1725387243481,
#    'version': 1,
#    'name': 'azure_sql_server_data_warehouses',
#    'description': 'azure_sql_server_data_warehouses',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure SQL Data Warehouse',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'azure_sql_server',
#     'name': 'dataWarehouses',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'azure_sql_dw',
#     'name': 'server',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '29cad1a8-172d-75ba-5697-483173f15ed9',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243486,
#    'updateTime': 1725387243486,
#    'version': 1,
#    'name': 'parquet_schema_columns',
#    'description': 'parquet_schema_columns',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'parquet_schema',
#     'name': 'columns',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'parquet_schema_element',
#     'name': 'parentSchema',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '37db1f59-3f11-1e63-7618-73f12a5880a7',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243480,
#    'updateTime': 1725387243480,
#    'version': 1,
#    'name': 'mysql_db_tables',
#    'description': 'mysql_db_tables',
#    'typeVersion': '1.0',
#    'serviceType': 'MySQL',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'mysql_db',
#     'name': 'tables',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'mysql_table',
#     'name': 'db',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': 'dc9489e5-c843-9889-784f-a47e58f3d558',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243489,
#    'updateTime': 1725387243489,
#    'version': 1,
#    'name': 'tableau_project_datasources',
#    'description': 'tableau_project_datasources',
#    'typeVersion': '1.0',
#    'serviceType': 'Tableau Server',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'tableau_project',
#     'name': 'datasources',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'tableau_datasource',
#     'name': 'project',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '574665fd-e6e2-2743-b661-1593788a1fb6',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243487,
#    'updateTime': 1725387243487,
#    'version': 1,
#    'name': 'sap_hana_table_table_columns',
#    'description': 'sap_hana_table_table_columns',
#    'typeVersion': '1.0',
#    'serviceType': 'SAP HANA',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'sap_hana_table',
#     'name': 'table_columns',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'sap_hana_table_column',
#     'name': 'table',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '9aa94d03-0d7d-0940-eb9f-e12a44854578',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243489,
#    'updateTime': 1725387243489,
#    'version': 1,
#    'name': 'qlik_sense_server_apps',
#    'description': 'qlik_sense_server_apps',
#    'typeVersion': '1.0',
#    'serviceType': 'Qlik Sense',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'qlik_sense_server',
#     'name': 'apps',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'qlik_sense_app',
#     'name': 'sense_server',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '3ba599c4-15c7-d3f0-76e3-53e961304e0f',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243481,
#    'updateTime': 1725387243481,
#    'version': 1,
#    'name': 'azure_sql_mi_table_columns',
#    'description': 'azure_sql_mi_table_columns',
#    'typeVersion': '1.0',
#    'serviceType': 'Azure SQL Managed Instance',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'azure_sql_mi_table',
#     'name': 'columns',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'azure_sql_mi_column',
#     'name': 'table',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '6976fc1b-bfa4-c366-3a89-0648940fea4c',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243488,
#    'updateTime': 1725387243488,
#    'version': 1,
#    'name': 'erwin_domain_deriveddomains',
#    'description': 'erwin_domain_deriveddomains',
#    'typeVersion': '1.0',
#    'serviceType': 'Erwin',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'ASSOCIATION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'erwin_domain',
#     'name': 'deriveddomains',
#     'isContainer': False,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'erwin_domain',
#     'name': 'domain',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}},
#   {'category': 'RELATIONSHIP',
#    'guid': '94dced37-45a9-7660-f63d-fd2ab949da82',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243487,
#    'updateTime': 1725387243487,
#    'version': 1,
#    'name': 'bigquery_dataset_tables',
#    'description': 'bigquery_dataset_tables',
#    'typeVersion': '1.0',
#    'serviceType': 'Google BigQuery',
#    'lastModifiedTS': '1',
#    'attributeDefs': [],
#    'relationshipCategory': 'COMPOSITION',
#    'propagateTags': 'NONE',
#    'endDef1': {'type': 'bigquery_dataset',
#     'name': 'tables',
#     'isContainer': True,
#     'cardinality': 'SET',
#     'isLegacyAttribute': False},
#    'endDef2': {'type': 'bigquery_table',
#     'name': 'dataset',
#     'isContainer': False,
#     'cardinality': 'SINGLE',
#     'isLegacyAttribute': False}}],
#  'termTemplateDefs': [],
#  'businessMetadataDefs': [{'category': 'BUSINESS_METADATA',
#    'guid': 'd2aebee6-693d-4e4e-bfe4-dbce2d4ef676',
#    'createdBy': 'admin',
#    'updatedBy': 'admin',
#    'createTime': 1725387243477,
#    'updateTime': 1725387243477,
#    'version': 1,
#    'name': 'PurviewDataQuality',
#    'description': 'PurviewDataQuality',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '1',
#    'attributeDefs': [{'name': 'overallScore',
#      'typeName': 'double',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'options': {'applicableEntityTypes': '["DataSet"]'}},
#     {'name': 'dimensionScores',
#      'typeName': 'map<string,double>',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'options': {'applicableEntityTypes': '["DataSet"]'}},
#     {'name': 'lastAssessmentAt',
#      'typeName': 'date',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'options': {'applicableEntityTypes': '["DataSet"]'}},
#     {'name': 'lastFullProfileAt',
#      'typeName': 'date',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'options': {'applicableEntityTypes': '["DataSet"]'}},
#     {'name': 'lastSampleProfileAt',
#      'typeName': 'date',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'options': {'applicableEntityTypes': '["DataSet"]'}}]},
#   {'category': 'BUSINESS_METADATA',
#    'guid': '58e8cf69-e46f-460f-a867-10bd01a8bf4f',
#    'createdBy': '6617cad6-d329-4361-951a-9eacbbaa8049',
#    'updatedBy': 'd644b8b0-aaed-4b93-b79d-329be607a0f9',
#    'createTime': 1720769406228,
#    'updateTime': 1723021851621,
#    'version': 4,
#    'name': 'Analytics',
#    'description': 'Analytics',
#    'typeVersion': '1.0',
#    'lastModifiedTS': '4',
#    'attributeDefs': [{'name': 'Report',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'options': {'maxStrLength': '32000',
#       'isDisabled': 'false',
#       'applicableEntityTypes': '["Purview_Report"]'}},
#     {'name': 'Dashboard',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'options': {'maxStrLength': '32000',
#       'isDisabled': 'false',
#       'applicableEntityTypes': '["Purview_Dashboard"]'}},
#     {'name': 'new field data product TDF',
#      'typeName': 'string',
#      'isOptional': True,
#      'cardinality': 'SINGLE',
#      'valuesMinCount': 0,
#      'valuesMaxCount': 1,
#      'isUnique': False,
#      'isIndexable': True,
#      'includeInNotification': False,
#      'description': 'test',
#      'options': {'maxStrLength': '32000',
#       'isDisabled': 'false',
#       'applicableEntityTypes': '["Purview_Product"]'}}]}]}

# %%
# Check if the table exists in Purview
def check_entity_if_exist(client, qualifiedName, typeName):
    entities = client.get_entity(qualifiedName=qualifiedName, typeName=typeName)
    return len(entities) > 0

# %%
procType = EntityTypeDef(
    "ProcessCustomSnowflake",
    superTypes=["Process"],
    attributeDefs = [
        AtlasAttributeDef("columnMapping")
    ]
)

# Upload the type definition
type_results = client.upload_typedefs(entityDefs=[procType], force_update=True)
print(json.dumps(type_results,indent=2))
# Out:
# {
#   "enumDefs": [],
#   "structDefs": [],
#   "classificationDefs": [],
#   "entityDefs": [
#     {
#       "category": "ENTITY",
#       "guid": "77a19aa1-5d9e-fb22-b544-ba12d5c1603d",
#       "createdBy": "b239f754-726d-4331-b452-0155f65046fa",
#       "updatedBy": "b239f754-726d-4331-b452-0155f65046fa",
#       "createTime": 1726385724201,
#       "updateTime": 1726387997959,
#       "version": 2,
#       "name": "ProcessCustomSnowflake",
#       "description": "ProcessCustomSnowflake",
#       "typeVersion": "1.0",
#       "lastModifiedTS": "2",
#       "attributeDefs": [
#         {
#           "name": "columnMapping",
#           "typeName": "string",
#           "isOptional": true,
#           "cardinality": "SINGLE",
#           "valuesMinCount": 0,
#           "valuesMaxCount": 1,
#           "isUnique": false,
#           "isIndexable": false,
#           "includeInNotification": false
#         }
#       ],
#       "superTypes": [
#         "Process"
#       ],
#       "subTypes": [],
#       "relationshipAttributeDefs": [
#         {
#           "name": "represents",
#           "typeName": "Purview_DataDomain",
#           "isOptional": true,
#           "cardinality": "SINGLE",
#           "valuesMinCount": -1,
#           "valuesMaxCount": -1,
#           "isUnique": false,
#           "isIndexable": false,
#           "includeInNotification": false,
#           "relationshipTypeName": "Purview_Assets_DataDomain_Represents",
#           "isLegacyAttribute": false
#         },
#         {
#           "name": "outputs",
#           "typeName": "array<DataSet>",
#           "isOptional": true,
#           "cardinality": "SET",
#           "valuesMinCount": 0,
#           "valuesMaxCount": 2147483647,
#           "isUnique": false,
#           "isIndexable": false,
#           "includeInNotification": false,
#           "relationshipTypeName": "process_dataset_outputs",
#           "isLegacyAttribute": true
#         },
#         {
#           "name": "inputs",
#           "typeName": "array<DataSet>",
#           "isOptional": true,
#           "cardinality": "SET",
#           "valuesMinCount": 0,
#           "valuesMaxCount": 2147483647,
#           "isUnique": false,
#           "isIndexable": false,
#           "includeInNotification": false,
#           "relationshipTypeName": "dataset_process_inputs",
#           "isLegacyAttribute": true
#         },
#         {
#           "name": "meanings",
#           "typeName": "array<AtlasGlossaryTerm>",
#           "isOptional": true,
#           "cardinality": "SET",
#           "valuesMinCount": -1,
#           "valuesMaxCount": -1,
#           "isUnique": false,
#           "isIndexable": false,
#           "includeInNotification": false,
#           "relationshipTypeName": "AtlasGlossarySemanticAssignment",
#           "isLegacyAttribute": false
#         }
#       ],
#       "businessAttributeDefs": {}
#     }
#   ],
#   "relationshipDefs": [],
#   "termTemplateDefs": [],
#   "businessMetadataDefs": []
# }

# %%
cur = conn.cursor()

# Execute a statement that will generate a result set.
sql = f"""SELECT
        S.TABLE_CATALOG as SourceCatalog,
        S.TABLE_SCHEMA as SourceSchema,
        S.TABLE_NAME as SourceTable,
        S.COLUMN_NAME as SourceColumn,
        S.DATA_TYPE as SourceColumnType,
        T.TABLE_CATALOG as TargetCatalog,
        T.TABLE_SCHEMA as TargetSchema,
        T.TABLE_NAME as TargetTable,
        T.COLUMN_NAME as TargetColumn,
        T.DATA_TYPE as TargetColumnType
   FROM SNOWFLAKE_SAMPLE_DATA.INFORMATION_SCHEMA.COLUMNS S
   JOIN SNOWFLAKE_SAMPLE_DATA.INFORMATION_SCHEMA.COLUMNS T ON S.TABLE_NAME = T.TABLE_NAME AND S.COLUMN_NAME = T.COLUMN_NAME
   WHERE S.TABLE_SCHEMA = 'TPCDS_SF10TCL' AND T.TABLE_SCHEMA = 'TPCDS_SF100TCL'"""

cur.execute(sql)

# Fetch the result set from the cursor and deliver it as the pandas DataFrame.
df = cur.fetch_pandas_all()
#print(df)
jsonSchema = []
df = df.sort_values(by=["SOURCECATALOG","SOURCESCHEMA","SOURCETABLE","SOURCECOLUMN"], ascending=True)
tables = df.groupby(["SOURCETABLE","TARGETTABLE"]).groups

for rec in tables:
    SourceTableName=rec[0]
    TargetTableName=rec[1]
    
    
    SourceQualifiedName= f"""snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/{SourceTableName}"""
    TargetQualifiedName= f"""snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/{TargetTableName}"""
    #print(SourceQualifiedName)

    if check_entity_if_exist(client, SourceQualifiedName, "snowflake_table"):
        SourceLineage = AtlasEntity(
            name=SourceTableName,
            typeName="snowflake_table",
            qualified_name=SourceQualifiedName,
            #guid=str(uuid.uuid4())
        )
    if check_entity_if_exist(client, TargetQualifiedName, "snowflake_table"):
        TargetLineage = AtlasEntity(
            name=TargetTableName,
            typeName="snowflake_table",
            qualified_name=TargetQualifiedName,
            #guid=str(uuid.uuid4())
        )

    ListMapping = []
    columns = df[(df["SOURCETABLE"] == SourceTableName) & (df["TARGETTABLE"] == TargetTableName)].groupby(["SOURCECOLUMN","SOURCECOLUMNTYPE","TARGETCOLUMN","TARGETCOLUMNTYPE"]).groups
    #print(columns)  
    for SOURCECOLUMN,SOURCECOLUMNTYPE, TARGETCOLUMN,TARGETCOLUMNTYPE in columns:
        #print(SOURCECOLUMN)
        ListMapping.append({"Source": f"{SOURCECOLUMN}", "Sink": f"{TARGETCOLUMN}"})
      
    #print(ListMapping)
    column_mapping = [
        # This object defines the column lineage between input01 and output01
        {"ColumnMapping": ListMapping,
            "DatasetMapping": {
            "Source": SourceLineage.qualifiedName, "Sink": TargetLineage.qualifiedName}
        }
    ]
    print(column_mapping)
    #Custom Process for Snowflake with Column Lineage
    process_qn = f"""snowflake://sqlqueryfrom{SourceTableName}to{TargetTableName}"""
    process_type_name = "ProcessCustomSnowflake"

    vuuid = "-"+ str(uuid.uuid4())
    process = AtlasProcess(
        name="Snowflake query",
        typeName=process_type_name,
        qualified_name=process_qn,
        inputs=[SourceLineage],
        outputs=[TargetLineage],
        guid=vuuid,
        attributes={"columnMapping": json.dumps(column_mapping)}
    )
    results = client.upload_entities(batch=[process])
# Out:
# [{'ColumnMapping': [{'Source': 'CC_CALL_CENTER_ID', 'Sink': 'CC_CALL_CENTER_ID'}, {'Source': 'CC_CALL_CENTER_SK', 'Sink': 'CC_CALL_CENTER_SK'}, {'Source': 'CC_CITY', 'Sink': 'CC_CITY'}, {'Source': 'CC_CLASS', 'Sink': 'CC_CLASS'}, {'Source': 'CC_CLOSED_DATE_SK', 'Sink': 'CC_CLOSED_DATE_SK'}, {'Source': 'CC_COMPANY', 'Sink': 'CC_COMPANY'}, {'Source': 'CC_COMPANY_NAME', 'Sink': 'CC_COMPANY_NAME'}, {'Source': 'CC_COUNTRY', 'Sink': 'CC_COUNTRY'}, {'Source': 'CC_COUNTY', 'Sink': 'CC_COUNTY'}, {'Source': 'CC_DIVISION', 'Sink': 'CC_DIVISION'}, {'Source': 'CC_DIVISION_NAME', 'Sink': 'CC_DIVISION_NAME'}, {'Source': 'CC_EMPLOYEES', 'Sink': 'CC_EMPLOYEES'}, {'Source': 'CC_GMT_OFFSET', 'Sink': 'CC_GMT_OFFSET'}, {'Source': 'CC_HOURS', 'Sink': 'CC_HOURS'}, {'Source': 'CC_MANAGER', 'Sink': 'CC_MANAGER'}, {'Source': 'CC_MARKET_MANAGER', 'Sink': 'CC_MARKET_MANAGER'}, {'Source': 'CC_MKT_CLASS', 'Sink': 'CC_MKT_CLASS'}, {'Source': 'CC_MKT_DESC', 'Sink': 'CC_MKT_DESC'}, {'Source': 'CC_MKT_ID', 'Sink': 'CC_MKT_ID'}, {'Source': 'CC_NAME', 'Sink': 'CC_NAME'}, {'Source': 'CC_OPEN_DATE_SK', 'Sink': 'CC_OPEN_DATE_SK'}, {'Source': 'CC_REC_END_DATE', 'Sink': 'CC_REC_END_DATE'}, {'Source': 'CC_REC_START_DATE', 'Sink': 'CC_REC_START_DATE'}, {'Source': 'CC_SQ_FT', 'Sink': 'CC_SQ_FT'}, {'Source': 'CC_STATE', 'Sink': 'CC_STATE'}, {'Source': 'CC_STREET_NAME', 'Sink': 'CC_STREET_NAME'}, {'Source': 'CC_STREET_NUMBER', 'Sink': 'CC_STREET_NUMBER'}, {'Source': 'CC_STREET_TYPE', 'Sink': 'CC_STREET_TYPE'}, {'Source': 'CC_SUITE_NUMBER', 'Sink': 'CC_SUITE_NUMBER'}, {'Source': 'CC_TAX_PERCENTAGE', 'Sink': 'CC_TAX_PERCENTAGE'}, {'Source': 'CC_ZIP', 'Sink': 'CC_ZIP'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/CALL_CENTER', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/CALL_CENTER'}}]
# [{'ColumnMapping': [{'Source': 'CP_CATALOG_NUMBER', 'Sink': 'CP_CATALOG_NUMBER'}, {'Source': 'CP_CATALOG_PAGE_ID', 'Sink': 'CP_CATALOG_PAGE_ID'}, {'Source': 'CP_CATALOG_PAGE_NUMBER', 'Sink': 'CP_CATALOG_PAGE_NUMBER'}, {'Source': 'CP_CATALOG_PAGE_SK', 'Sink': 'CP_CATALOG_PAGE_SK'}, {'Source': 'CP_DEPARTMENT', 'Sink': 'CP_DEPARTMENT'}, {'Source': 'CP_DESCRIPTION', 'Sink': 'CP_DESCRIPTION'}, {'Source': 'CP_END_DATE_SK', 'Sink': 'CP_END_DATE_SK'}, {'Source': 'CP_START_DATE_SK', 'Sink': 'CP_START_DATE_SK'}, {'Source': 'CP_TYPE', 'Sink': 'CP_TYPE'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/CATALOG_PAGE', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/CATALOG_PAGE'}}]
# [{'ColumnMapping': [{'Source': 'CR_CALL_CENTER_SK', 'Sink': 'CR_CALL_CENTER_SK'}, {'Source': 'CR_CATALOG_PAGE_SK', 'Sink': 'CR_CATALOG_PAGE_SK'}, {'Source': 'CR_FEE', 'Sink': 'CR_FEE'}, {'Source': 'CR_ITEM_SK', 'Sink': 'CR_ITEM_SK'}, {'Source': 'CR_NET_LOSS', 'Sink': 'CR_NET_LOSS'}, {'Source': 'CR_ORDER_NUMBER', 'Sink': 'CR_ORDER_NUMBER'}, {'Source': 'CR_REASON_SK', 'Sink': 'CR_REASON_SK'}, {'Source': 'CR_REFUNDED_ADDR_SK', 'Sink': 'CR_REFUNDED_ADDR_SK'}, {'Source': 'CR_REFUNDED_CASH', 'Sink': 'CR_REFUNDED_CASH'}, {'Source': 'CR_REFUNDED_CDEMO_SK', 'Sink': 'CR_REFUNDED_CDEMO_SK'}, {'Source': 'CR_REFUNDED_CUSTOMER_SK', 'Sink': 'CR_REFUNDED_CUSTOMER_SK'}, {'Source': 'CR_REFUNDED_HDEMO_SK', 'Sink': 'CR_REFUNDED_HDEMO_SK'}, {'Source': 'CR_RETURNED_DATE_SK', 'Sink': 'CR_RETURNED_DATE_SK'}, {'Source': 'CR_RETURNED_TIME_SK', 'Sink': 'CR_RETURNED_TIME_SK'}, {'Source': 'CR_RETURNING_ADDR_SK', 'Sink': 'CR_RETURNING_ADDR_SK'}, {'Source': 'CR_RETURNING_CDEMO_SK', 'Sink': 'CR_RETURNING_CDEMO_SK'}, {'Source': 'CR_RETURNING_CUSTOMER_SK', 'Sink': 'CR_RETURNING_CUSTOMER_SK'}, {'Source': 'CR_RETURNING_HDEMO_SK', 'Sink': 'CR_RETURNING_HDEMO_SK'}, {'Source': 'CR_RETURN_AMOUNT', 'Sink': 'CR_RETURN_AMOUNT'}, {'Source': 'CR_RETURN_AMT_INC_TAX', 'Sink': 'CR_RETURN_AMT_INC_TAX'}, {'Source': 'CR_RETURN_QUANTITY', 'Sink': 'CR_RETURN_QUANTITY'}, {'Source': 'CR_RETURN_SHIP_COST', 'Sink': 'CR_RETURN_SHIP_COST'}, {'Source': 'CR_RETURN_TAX', 'Sink': 'CR_RETURN_TAX'}, {'Source': 'CR_REVERSED_CHARGE', 'Sink': 'CR_REVERSED_CHARGE'}, {'Source': 'CR_SHIP_MODE_SK', 'Sink': 'CR_SHIP_MODE_SK'}, {'Source': 'CR_STORE_CREDIT', 'Sink': 'CR_STORE_CREDIT'}, {'Source': 'CR_WAREHOUSE_SK', 'Sink': 'CR_WAREHOUSE_SK'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/CATALOG_RETURNS', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/CATALOG_RETURNS'}}]
# [{'ColumnMapping': [{'Source': 'CS_BILL_ADDR_SK', 'Sink': 'CS_BILL_ADDR_SK'}, {'Source': 'CS_BILL_CDEMO_SK', 'Sink': 'CS_BILL_CDEMO_SK'}, {'Source': 'CS_BILL_CUSTOMER_SK', 'Sink': 'CS_BILL_CUSTOMER_SK'}, {'Source': 'CS_BILL_HDEMO_SK', 'Sink': 'CS_BILL_HDEMO_SK'}, {'Source': 'CS_CALL_CENTER_SK', 'Sink': 'CS_CALL_CENTER_SK'}, {'Source': 'CS_CATALOG_PAGE_SK', 'Sink': 'CS_CATALOG_PAGE_SK'}, {'Source': 'CS_COUPON_AMT', 'Sink': 'CS_COUPON_AMT'}, {'Source': 'CS_EXT_DISCOUNT_AMT', 'Sink': 'CS_EXT_DISCOUNT_AMT'}, {'Source': 'CS_EXT_LIST_PRICE', 'Sink': 'CS_EXT_LIST_PRICE'}, {'Source': 'CS_EXT_SALES_PRICE', 'Sink': 'CS_EXT_SALES_PRICE'}, {'Source': 'CS_EXT_SHIP_COST', 'Sink': 'CS_EXT_SHIP_COST'}, {'Source': 'CS_EXT_TAX', 'Sink': 'CS_EXT_TAX'}, {'Source': 'CS_EXT_WHOLESALE_COST', 'Sink': 'CS_EXT_WHOLESALE_COST'}, {'Source': 'CS_ITEM_SK', 'Sink': 'CS_ITEM_SK'}, {'Source': 'CS_LIST_PRICE', 'Sink': 'CS_LIST_PRICE'}, {'Source': 'CS_NET_PAID', 'Sink': 'CS_NET_PAID'}, {'Source': 'CS_NET_PAID_INC_SHIP', 'Sink': 'CS_NET_PAID_INC_SHIP'}, {'Source': 'CS_NET_PAID_INC_SHIP_TAX', 'Sink': 'CS_NET_PAID_INC_SHIP_TAX'}, {'Source': 'CS_NET_PAID_INC_TAX', 'Sink': 'CS_NET_PAID_INC_TAX'}, {'Source': 'CS_NET_PROFIT', 'Sink': 'CS_NET_PROFIT'}, {'Source': 'CS_ORDER_NUMBER', 'Sink': 'CS_ORDER_NUMBER'}, {'Source': 'CS_PROMO_SK', 'Sink': 'CS_PROMO_SK'}, {'Source': 'CS_QUANTITY', 'Sink': 'CS_QUANTITY'}, {'Source': 'CS_SALES_PRICE', 'Sink': 'CS_SALES_PRICE'}, {'Source': 'CS_SHIP_ADDR_SK', 'Sink': 'CS_SHIP_ADDR_SK'}, {'Source': 'CS_SHIP_CDEMO_SK', 'Sink': 'CS_SHIP_CDEMO_SK'}, {'Source': 'CS_SHIP_CUSTOMER_SK', 'Sink': 'CS_SHIP_CUSTOMER_SK'}, {'Source': 'CS_SHIP_DATE_SK', 'Sink': 'CS_SHIP_DATE_SK'}, {'Source': 'CS_SHIP_HDEMO_SK', 'Sink': 'CS_SHIP_HDEMO_SK'}, {'Source': 'CS_SHIP_MODE_SK', 'Sink': 'CS_SHIP_MODE_SK'}, {'Source': 'CS_SOLD_DATE_SK', 'Sink': 'CS_SOLD_DATE_SK'}, {'Source': 'CS_SOLD_TIME_SK', 'Sink': 'CS_SOLD_TIME_SK'}, {'Source': 'CS_WAREHOUSE_SK', 'Sink': 'CS_WAREHOUSE_SK'}, {'Source': 'CS_WHOLESALE_COST', 'Sink': 'CS_WHOLESALE_COST'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/CATALOG_SALES', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/CATALOG_SALES'}}]
# [{'ColumnMapping': [{'Source': 'C_BIRTH_COUNTRY', 'Sink': 'C_BIRTH_COUNTRY'}, {'Source': 'C_BIRTH_DAY', 'Sink': 'C_BIRTH_DAY'}, {'Source': 'C_BIRTH_MONTH', 'Sink': 'C_BIRTH_MONTH'}, {'Source': 'C_BIRTH_YEAR', 'Sink': 'C_BIRTH_YEAR'}, {'Source': 'C_CURRENT_ADDR_SK', 'Sink': 'C_CURRENT_ADDR_SK'}, {'Source': 'C_CURRENT_CDEMO_SK', 'Sink': 'C_CURRENT_CDEMO_SK'}, {'Source': 'C_CURRENT_HDEMO_SK', 'Sink': 'C_CURRENT_HDEMO_SK'}, {'Source': 'C_CUSTOMER_ID', 'Sink': 'C_CUSTOMER_ID'}, {'Source': 'C_CUSTOMER_SK', 'Sink': 'C_CUSTOMER_SK'}, {'Source': 'C_EMAIL_ADDRESS', 'Sink': 'C_EMAIL_ADDRESS'}, {'Source': 'C_FIRST_NAME', 'Sink': 'C_FIRST_NAME'}, {'Source': 'C_FIRST_SALES_DATE_SK', 'Sink': 'C_FIRST_SALES_DATE_SK'}, {'Source': 'C_FIRST_SHIPTO_DATE_SK', 'Sink': 'C_FIRST_SHIPTO_DATE_SK'}, {'Source': 'C_LAST_NAME', 'Sink': 'C_LAST_NAME'}, {'Source': 'C_LAST_REVIEW_DATE', 'Sink': 'C_LAST_REVIEW_DATE'}, {'Source': 'C_LOGIN', 'Sink': 'C_LOGIN'}, {'Source': 'C_PREFERRED_CUST_FLAG', 'Sink': 'C_PREFERRED_CUST_FLAG'}, {'Source': 'C_SALUTATION', 'Sink': 'C_SALUTATION'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/CUSTOMER', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/CUSTOMER'}}]
# [{'ColumnMapping': [{'Source': 'CA_ADDRESS_ID', 'Sink': 'CA_ADDRESS_ID'}, {'Source': 'CA_ADDRESS_SK', 'Sink': 'CA_ADDRESS_SK'}, {'Source': 'CA_CITY', 'Sink': 'CA_CITY'}, {'Source': 'CA_COUNTRY', 'Sink': 'CA_COUNTRY'}, {'Source': 'CA_COUNTY', 'Sink': 'CA_COUNTY'}, {'Source': 'CA_GMT_OFFSET', 'Sink': 'CA_GMT_OFFSET'}, {'Source': 'CA_LOCATION_TYPE', 'Sink': 'CA_LOCATION_TYPE'}, {'Source': 'CA_STATE', 'Sink': 'CA_STATE'}, {'Source': 'CA_STREET_NAME', 'Sink': 'CA_STREET_NAME'}, {'Source': 'CA_STREET_NUMBER', 'Sink': 'CA_STREET_NUMBER'}, {'Source': 'CA_STREET_TYPE', 'Sink': 'CA_STREET_TYPE'}, {'Source': 'CA_SUITE_NUMBER', 'Sink': 'CA_SUITE_NUMBER'}, {'Source': 'CA_ZIP', 'Sink': 'CA_ZIP'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/CUSTOMER_ADDRESS', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/CUSTOMER_ADDRESS'}}]
# [{'ColumnMapping': [{'Source': 'CD_CREDIT_RATING', 'Sink': 'CD_CREDIT_RATING'}, {'Source': 'CD_DEMO_SK', 'Sink': 'CD_DEMO_SK'}, {'Source': 'CD_DEP_COLLEGE_COUNT', 'Sink': 'CD_DEP_COLLEGE_COUNT'}, {'Source': 'CD_DEP_COUNT', 'Sink': 'CD_DEP_COUNT'}, {'Source': 'CD_DEP_EMPLOYED_COUNT', 'Sink': 'CD_DEP_EMPLOYED_COUNT'}, {'Source': 'CD_EDUCATION_STATUS', 'Sink': 'CD_EDUCATION_STATUS'}, {'Source': 'CD_GENDER', 'Sink': 'CD_GENDER'}, {'Source': 'CD_MARITAL_STATUS', 'Sink': 'CD_MARITAL_STATUS'}, {'Source': 'CD_PURCHASE_ESTIMATE', 'Sink': 'CD_PURCHASE_ESTIMATE'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/CUSTOMER_DEMOGRAPHICS', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/CUSTOMER_DEMOGRAPHICS'}}]
# [{'ColumnMapping': [{'Source': 'D_CURRENT_DAY', 'Sink': 'D_CURRENT_DAY'}, {'Source': 'D_CURRENT_MONTH', 'Sink': 'D_CURRENT_MONTH'}, {'Source': 'D_CURRENT_QUARTER', 'Sink': 'D_CURRENT_QUARTER'}, {'Source': 'D_CURRENT_WEEK', 'Sink': 'D_CURRENT_WEEK'}, {'Source': 'D_CURRENT_YEAR', 'Sink': 'D_CURRENT_YEAR'}, {'Source': 'D_DATE', 'Sink': 'D_DATE'}, {'Source': 'D_DATE_ID', 'Sink': 'D_DATE_ID'}, {'Source': 'D_DATE_SK', 'Sink': 'D_DATE_SK'}, {'Source': 'D_DAY_NAME', 'Sink': 'D_DAY_NAME'}, {'Source': 'D_DOM', 'Sink': 'D_DOM'}, {'Source': 'D_DOW', 'Sink': 'D_DOW'}, {'Source': 'D_FIRST_DOM', 'Sink': 'D_FIRST_DOM'}, {'Source': 'D_FOLLOWING_HOLIDAY', 'Sink': 'D_FOLLOWING_HOLIDAY'}, {'Source': 'D_FY_QUARTER_SEQ', 'Sink': 'D_FY_QUARTER_SEQ'}, {'Source': 'D_FY_WEEK_SEQ', 'Sink': 'D_FY_WEEK_SEQ'}, {'Source': 'D_FY_YEAR', 'Sink': 'D_FY_YEAR'}, {'Source': 'D_HOLIDAY', 'Sink': 'D_HOLIDAY'}, {'Source': 'D_LAST_DOM', 'Sink': 'D_LAST_DOM'}, {'Source': 'D_MONTH_SEQ', 'Sink': 'D_MONTH_SEQ'}, {'Source': 'D_MOY', 'Sink': 'D_MOY'}, {'Source': 'D_QOY', 'Sink': 'D_QOY'}, {'Source': 'D_QUARTER_NAME', 'Sink': 'D_QUARTER_NAME'}, {'Source': 'D_QUARTER_SEQ', 'Sink': 'D_QUARTER_SEQ'}, {'Source': 'D_SAME_DAY_LQ', 'Sink': 'D_SAME_DAY_LQ'}, {'Source': 'D_SAME_DAY_LY', 'Sink': 'D_SAME_DAY_LY'}, {'Source': 'D_WEEKEND', 'Sink': 'D_WEEKEND'}, {'Source': 'D_WEEK_SEQ', 'Sink': 'D_WEEK_SEQ'}, {'Source': 'D_YEAR', 'Sink': 'D_YEAR'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/DATE_DIM', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/DATE_DIM'}}]
# [{'ColumnMapping': [{'Source': 'HD_BUY_POTENTIAL', 'Sink': 'HD_BUY_POTENTIAL'}, {'Source': 'HD_DEMO_SK', 'Sink': 'HD_DEMO_SK'}, {'Source': 'HD_DEP_COUNT', 'Sink': 'HD_DEP_COUNT'}, {'Source': 'HD_INCOME_BAND_SK', 'Sink': 'HD_INCOME_BAND_SK'}, {'Source': 'HD_VEHICLE_COUNT', 'Sink': 'HD_VEHICLE_COUNT'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/HOUSEHOLD_DEMOGRAPHICS', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/HOUSEHOLD_DEMOGRAPHICS'}}]
# [{'ColumnMapping': [{'Source': 'IB_INCOME_BAND_SK', 'Sink': 'IB_INCOME_BAND_SK'}, {'Source': 'IB_LOWER_BOUND', 'Sink': 'IB_LOWER_BOUND'}, {'Source': 'IB_UPPER_BOUND', 'Sink': 'IB_UPPER_BOUND'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/INCOME_BAND', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/INCOME_BAND'}}]
# [{'ColumnMapping': [{'Source': 'INV_DATE_SK', 'Sink': 'INV_DATE_SK'}, {'Source': 'INV_ITEM_SK', 'Sink': 'INV_ITEM_SK'}, {'Source': 'INV_QUANTITY_ON_HAND', 'Sink': 'INV_QUANTITY_ON_HAND'}, {'Source': 'INV_WAREHOUSE_SK', 'Sink': 'INV_WAREHOUSE_SK'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/INVENTORY', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/INVENTORY'}}]
# [{'ColumnMapping': [{'Source': 'I_BRAND', 'Sink': 'I_BRAND'}, {'Source': 'I_BRAND_ID', 'Sink': 'I_BRAND_ID'}, {'Source': 'I_CATEGORY', 'Sink': 'I_CATEGORY'}, {'Source': 'I_CATEGORY_ID', 'Sink': 'I_CATEGORY_ID'}, {'Source': 'I_CLASS', 'Sink': 'I_CLASS'}, {'Source': 'I_CLASS_ID', 'Sink': 'I_CLASS_ID'}, {'Source': 'I_COLOR', 'Sink': 'I_COLOR'}, {'Source': 'I_CONTAINER', 'Sink': 'I_CONTAINER'}, {'Source': 'I_CURRENT_PRICE', 'Sink': 'I_CURRENT_PRICE'}, {'Source': 'I_FORMULATION', 'Sink': 'I_FORMULATION'}, {'Source': 'I_ITEM_DESC', 'Sink': 'I_ITEM_DESC'}, {'Source': 'I_ITEM_ID', 'Sink': 'I_ITEM_ID'}, {'Source': 'I_ITEM_SK', 'Sink': 'I_ITEM_SK'}, {'Source': 'I_MANAGER_ID', 'Sink': 'I_MANAGER_ID'}, {'Source': 'I_MANUFACT', 'Sink': 'I_MANUFACT'}, {'Source': 'I_MANUFACT_ID', 'Sink': 'I_MANUFACT_ID'}, {'Source': 'I_PRODUCT_NAME', 'Sink': 'I_PRODUCT_NAME'}, {'Source': 'I_REC_END_DATE', 'Sink': 'I_REC_END_DATE'}, {'Source': 'I_REC_START_DATE', 'Sink': 'I_REC_START_DATE'}, {'Source': 'I_SIZE', 'Sink': 'I_SIZE'}, {'Source': 'I_UNITS', 'Sink': 'I_UNITS'}, {'Source': 'I_WHOLESALE_COST', 'Sink': 'I_WHOLESALE_COST'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/ITEM', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/ITEM'}}]
# [{'ColumnMapping': [{'Source': 'P_CHANNEL_CATALOG', 'Sink': 'P_CHANNEL_CATALOG'}, {'Source': 'P_CHANNEL_DEMO', 'Sink': 'P_CHANNEL_DEMO'}, {'Source': 'P_CHANNEL_DETAILS', 'Sink': 'P_CHANNEL_DETAILS'}, {'Source': 'P_CHANNEL_DMAIL', 'Sink': 'P_CHANNEL_DMAIL'}, {'Source': 'P_CHANNEL_EMAIL', 'Sink': 'P_CHANNEL_EMAIL'}, {'Source': 'P_CHANNEL_EVENT', 'Sink': 'P_CHANNEL_EVENT'}, {'Source': 'P_CHANNEL_PRESS', 'Sink': 'P_CHANNEL_PRESS'}, {'Source': 'P_CHANNEL_RADIO', 'Sink': 'P_CHANNEL_RADIO'}, {'Source': 'P_CHANNEL_TV', 'Sink': 'P_CHANNEL_TV'}, {'Source': 'P_COST', 'Sink': 'P_COST'}, {'Source': 'P_DISCOUNT_ACTIVE', 'Sink': 'P_DISCOUNT_ACTIVE'}, {'Source': 'P_END_DATE_SK', 'Sink': 'P_END_DATE_SK'}, {'Source': 'P_ITEM_SK', 'Sink': 'P_ITEM_SK'}, {'Source': 'P_PROMO_ID', 'Sink': 'P_PROMO_ID'}, {'Source': 'P_PROMO_NAME', 'Sink': 'P_PROMO_NAME'}, {'Source': 'P_PROMO_SK', 'Sink': 'P_PROMO_SK'}, {'Source': 'P_PURPOSE', 'Sink': 'P_PURPOSE'}, {'Source': 'P_RESPONSE_TARGET', 'Sink': 'P_RESPONSE_TARGET'}, {'Source': 'P_START_DATE_SK', 'Sink': 'P_START_DATE_SK'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/PROMOTION', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/PROMOTION'}}]
# [{'ColumnMapping': [{'Source': 'R_REASON_DESC', 'Sink': 'R_REASON_DESC'}, {'Source': 'R_REASON_ID', 'Sink': 'R_REASON_ID'}, {'Source': 'R_REASON_SK', 'Sink': 'R_REASON_SK'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/REASON', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/REASON'}}]
# [{'ColumnMapping': [{'Source': 'SM_CARRIER', 'Sink': 'SM_CARRIER'}, {'Source': 'SM_CODE', 'Sink': 'SM_CODE'}, {'Source': 'SM_CONTRACT', 'Sink': 'SM_CONTRACT'}, {'Source': 'SM_SHIP_MODE_ID', 'Sink': 'SM_SHIP_MODE_ID'}, {'Source': 'SM_SHIP_MODE_SK', 'Sink': 'SM_SHIP_MODE_SK'}, {'Source': 'SM_TYPE', 'Sink': 'SM_TYPE'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/SHIP_MODE', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/SHIP_MODE'}}]
# [{'ColumnMapping': [{'Source': 'S_CITY', 'Sink': 'S_CITY'}, {'Source': 'S_CLOSED_DATE_SK', 'Sink': 'S_CLOSED_DATE_SK'}, {'Source': 'S_COMPANY_ID', 'Sink': 'S_COMPANY_ID'}, {'Source': 'S_COMPANY_NAME', 'Sink': 'S_COMPANY_NAME'}, {'Source': 'S_COUNTRY', 'Sink': 'S_COUNTRY'}, {'Source': 'S_COUNTY', 'Sink': 'S_COUNTY'}, {'Source': 'S_DIVISION_ID', 'Sink': 'S_DIVISION_ID'}, {'Source': 'S_DIVISION_NAME', 'Sink': 'S_DIVISION_NAME'}, {'Source': 'S_FLOOR_SPACE', 'Sink': 'S_FLOOR_SPACE'}, {'Source': 'S_GEOGRAPHY_CLASS', 'Sink': 'S_GEOGRAPHY_CLASS'}, {'Source': 'S_GMT_OFFSET', 'Sink': 'S_GMT_OFFSET'}, {'Source': 'S_HOURS', 'Sink': 'S_HOURS'}, {'Source': 'S_MANAGER', 'Sink': 'S_MANAGER'}, {'Source': 'S_MARKET_DESC', 'Sink': 'S_MARKET_DESC'}, {'Source': 'S_MARKET_ID', 'Sink': 'S_MARKET_ID'}, {'Source': 'S_MARKET_MANAGER', 'Sink': 'S_MARKET_MANAGER'}, {'Source': 'S_NUMBER_EMPLOYEES', 'Sink': 'S_NUMBER_EMPLOYEES'}, {'Source': 'S_REC_END_DATE', 'Sink': 'S_REC_END_DATE'}, {'Source': 'S_REC_START_DATE', 'Sink': 'S_REC_START_DATE'}, {'Source': 'S_STATE', 'Sink': 'S_STATE'}, {'Source': 'S_STORE_ID', 'Sink': 'S_STORE_ID'}, {'Source': 'S_STORE_NAME', 'Sink': 'S_STORE_NAME'}, {'Source': 'S_STORE_SK', 'Sink': 'S_STORE_SK'}, {'Source': 'S_STREET_NAME', 'Sink': 'S_STREET_NAME'}, {'Source': 'S_STREET_NUMBER', 'Sink': 'S_STREET_NUMBER'}, {'Source': 'S_STREET_TYPE', 'Sink': 'S_STREET_TYPE'}, {'Source': 'S_SUITE_NUMBER', 'Sink': 'S_SUITE_NUMBER'}, {'Source': 'S_TAX_PRECENTAGE', 'Sink': 'S_TAX_PRECENTAGE'}, {'Source': 'S_ZIP', 'Sink': 'S_ZIP'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/STORE', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/STORE'}}]
# [{'ColumnMapping': [{'Source': 'SR_ADDR_SK', 'Sink': 'SR_ADDR_SK'}, {'Source': 'SR_CDEMO_SK', 'Sink': 'SR_CDEMO_SK'}, {'Source': 'SR_CUSTOMER_SK', 'Sink': 'SR_CUSTOMER_SK'}, {'Source': 'SR_FEE', 'Sink': 'SR_FEE'}, {'Source': 'SR_HDEMO_SK', 'Sink': 'SR_HDEMO_SK'}, {'Source': 'SR_ITEM_SK', 'Sink': 'SR_ITEM_SK'}, {'Source': 'SR_NET_LOSS', 'Sink': 'SR_NET_LOSS'}, {'Source': 'SR_REASON_SK', 'Sink': 'SR_REASON_SK'}, {'Source': 'SR_REFUNDED_CASH', 'Sink': 'SR_REFUNDED_CASH'}, {'Source': 'SR_RETURNED_DATE_SK', 'Sink': 'SR_RETURNED_DATE_SK'}, {'Source': 'SR_RETURN_AMT', 'Sink': 'SR_RETURN_AMT'}, {'Source': 'SR_RETURN_AMT_INC_TAX', 'Sink': 'SR_RETURN_AMT_INC_TAX'}, {'Source': 'SR_RETURN_QUANTITY', 'Sink': 'SR_RETURN_QUANTITY'}, {'Source': 'SR_RETURN_SHIP_COST', 'Sink': 'SR_RETURN_SHIP_COST'}, {'Source': 'SR_RETURN_TAX', 'Sink': 'SR_RETURN_TAX'}, {'Source': 'SR_RETURN_TIME_SK', 'Sink': 'SR_RETURN_TIME_SK'}, {'Source': 'SR_REVERSED_CHARGE', 'Sink': 'SR_REVERSED_CHARGE'}, {'Source': 'SR_STORE_CREDIT', 'Sink': 'SR_STORE_CREDIT'}, {'Source': 'SR_STORE_SK', 'Sink': 'SR_STORE_SK'}, {'Source': 'SR_TICKET_NUMBER', 'Sink': 'SR_TICKET_NUMBER'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/STORE_RETURNS', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/STORE_RETURNS'}}]
# [{'ColumnMapping': [{'Source': 'SS_ADDR_SK', 'Sink': 'SS_ADDR_SK'}, {'Source': 'SS_CDEMO_SK', 'Sink': 'SS_CDEMO_SK'}, {'Source': 'SS_COUPON_AMT', 'Sink': 'SS_COUPON_AMT'}, {'Source': 'SS_CUSTOMER_SK', 'Sink': 'SS_CUSTOMER_SK'}, {'Source': 'SS_EXT_DISCOUNT_AMT', 'Sink': 'SS_EXT_DISCOUNT_AMT'}, {'Source': 'SS_EXT_LIST_PRICE', 'Sink': 'SS_EXT_LIST_PRICE'}, {'Source': 'SS_EXT_SALES_PRICE', 'Sink': 'SS_EXT_SALES_PRICE'}, {'Source': 'SS_EXT_TAX', 'Sink': 'SS_EXT_TAX'}, {'Source': 'SS_EXT_WHOLESALE_COST', 'Sink': 'SS_EXT_WHOLESALE_COST'}, {'Source': 'SS_HDEMO_SK', 'Sink': 'SS_HDEMO_SK'}, {'Source': 'SS_ITEM_SK', 'Sink': 'SS_ITEM_SK'}, {'Source': 'SS_LIST_PRICE', 'Sink': 'SS_LIST_PRICE'}, {'Source': 'SS_NET_PAID', 'Sink': 'SS_NET_PAID'}, {'Source': 'SS_NET_PAID_INC_TAX', 'Sink': 'SS_NET_PAID_INC_TAX'}, {'Source': 'SS_NET_PROFIT', 'Sink': 'SS_NET_PROFIT'}, {'Source': 'SS_PROMO_SK', 'Sink': 'SS_PROMO_SK'}, {'Source': 'SS_QUANTITY', 'Sink': 'SS_QUANTITY'}, {'Source': 'SS_SALES_PRICE', 'Sink': 'SS_SALES_PRICE'}, {'Source': 'SS_SOLD_DATE_SK', 'Sink': 'SS_SOLD_DATE_SK'}, {'Source': 'SS_SOLD_TIME_SK', 'Sink': 'SS_SOLD_TIME_SK'}, {'Source': 'SS_STORE_SK', 'Sink': 'SS_STORE_SK'}, {'Source': 'SS_TICKET_NUMBER', 'Sink': 'SS_TICKET_NUMBER'}, {'Source': 'SS_WHOLESALE_COST', 'Sink': 'SS_WHOLESALE_COST'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/STORE_SALES', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/STORE_SALES'}}]
# [{'ColumnMapping': [{'Source': 'T_AM_PM', 'Sink': 'T_AM_PM'}, {'Source': 'T_HOUR', 'Sink': 'T_HOUR'}, {'Source': 'T_MEAL_TIME', 'Sink': 'T_MEAL_TIME'}, {'Source': 'T_MINUTE', 'Sink': 'T_MINUTE'}, {'Source': 'T_SECOND', 'Sink': 'T_SECOND'}, {'Source': 'T_SHIFT', 'Sink': 'T_SHIFT'}, {'Source': 'T_SUB_SHIFT', 'Sink': 'T_SUB_SHIFT'}, {'Source': 'T_TIME', 'Sink': 'T_TIME'}, {'Source': 'T_TIME_ID', 'Sink': 'T_TIME_ID'}, {'Source': 'T_TIME_SK', 'Sink': 'T_TIME_SK'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/TIME_DIM', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/TIME_DIM'}}]
# [{'ColumnMapping': [{'Source': 'W_CITY', 'Sink': 'W_CITY'}, {'Source': 'W_COUNTRY', 'Sink': 'W_COUNTRY'}, {'Source': 'W_COUNTY', 'Sink': 'W_COUNTY'}, {'Source': 'W_GMT_OFFSET', 'Sink': 'W_GMT_OFFSET'}, {'Source': 'W_STATE', 'Sink': 'W_STATE'}, {'Source': 'W_STREET_NAME', 'Sink': 'W_STREET_NAME'}, {'Source': 'W_STREET_NUMBER', 'Sink': 'W_STREET_NUMBER'}, {'Source': 'W_STREET_TYPE', 'Sink': 'W_STREET_TYPE'}, {'Source': 'W_SUITE_NUMBER', 'Sink': 'W_SUITE_NUMBER'}, {'Source': 'W_WAREHOUSE_ID', 'Sink': 'W_WAREHOUSE_ID'}, {'Source': 'W_WAREHOUSE_NAME', 'Sink': 'W_WAREHOUSE_NAME'}, {'Source': 'W_WAREHOUSE_SK', 'Sink': 'W_WAREHOUSE_SK'}, {'Source': 'W_WAREHOUSE_SQ_FT', 'Sink': 'W_WAREHOUSE_SQ_FT'}, {'Source': 'W_ZIP', 'Sink': 'W_ZIP'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/WAREHOUSE', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/WAREHOUSE'}}]
# [{'ColumnMapping': [{'Source': 'WP_ACCESS_DATE_SK', 'Sink': 'WP_ACCESS_DATE_SK'}, {'Source': 'WP_AUTOGEN_FLAG', 'Sink': 'WP_AUTOGEN_FLAG'}, {'Source': 'WP_CHAR_COUNT', 'Sink': 'WP_CHAR_COUNT'}, {'Source': 'WP_CREATION_DATE_SK', 'Sink': 'WP_CREATION_DATE_SK'}, {'Source': 'WP_CUSTOMER_SK', 'Sink': 'WP_CUSTOMER_SK'}, {'Source': 'WP_IMAGE_COUNT', 'Sink': 'WP_IMAGE_COUNT'}, {'Source': 'WP_LINK_COUNT', 'Sink': 'WP_LINK_COUNT'}, {'Source': 'WP_MAX_AD_COUNT', 'Sink': 'WP_MAX_AD_COUNT'}, {'Source': 'WP_REC_END_DATE', 'Sink': 'WP_REC_END_DATE'}, {'Source': 'WP_REC_START_DATE', 'Sink': 'WP_REC_START_DATE'}, {'Source': 'WP_TYPE', 'Sink': 'WP_TYPE'}, {'Source': 'WP_URL', 'Sink': 'WP_URL'}, {'Source': 'WP_WEB_PAGE_ID', 'Sink': 'WP_WEB_PAGE_ID'}, {'Source': 'WP_WEB_PAGE_SK', 'Sink': 'WP_WEB_PAGE_SK'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/WEB_PAGE', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/WEB_PAGE'}}]
# [{'ColumnMapping': [{'Source': 'WR_ACCOUNT_CREDIT', 'Sink': 'WR_ACCOUNT_CREDIT'}, {'Source': 'WR_FEE', 'Sink': 'WR_FEE'}, {'Source': 'WR_ITEM_SK', 'Sink': 'WR_ITEM_SK'}, {'Source': 'WR_NET_LOSS', 'Sink': 'WR_NET_LOSS'}, {'Source': 'WR_ORDER_NUMBER', 'Sink': 'WR_ORDER_NUMBER'}, {'Source': 'WR_REASON_SK', 'Sink': 'WR_REASON_SK'}, {'Source': 'WR_REFUNDED_ADDR_SK', 'Sink': 'WR_REFUNDED_ADDR_SK'}, {'Source': 'WR_REFUNDED_CASH', 'Sink': 'WR_REFUNDED_CASH'}, {'Source': 'WR_REFUNDED_CDEMO_SK', 'Sink': 'WR_REFUNDED_CDEMO_SK'}, {'Source': 'WR_REFUNDED_CUSTOMER_SK', 'Sink': 'WR_REFUNDED_CUSTOMER_SK'}, {'Source': 'WR_REFUNDED_HDEMO_SK', 'Sink': 'WR_REFUNDED_HDEMO_SK'}, {'Source': 'WR_RETURNED_DATE_SK', 'Sink': 'WR_RETURNED_DATE_SK'}, {'Source': 'WR_RETURNED_TIME_SK', 'Sink': 'WR_RETURNED_TIME_SK'}, {'Source': 'WR_RETURNING_ADDR_SK', 'Sink': 'WR_RETURNING_ADDR_SK'}, {'Source': 'WR_RETURNING_CDEMO_SK', 'Sink': 'WR_RETURNING_CDEMO_SK'}, {'Source': 'WR_RETURNING_CUSTOMER_SK', 'Sink': 'WR_RETURNING_CUSTOMER_SK'}, {'Source': 'WR_RETURNING_HDEMO_SK', 'Sink': 'WR_RETURNING_HDEMO_SK'}, {'Source': 'WR_RETURN_AMT', 'Sink': 'WR_RETURN_AMT'}, {'Source': 'WR_RETURN_AMT_INC_TAX', 'Sink': 'WR_RETURN_AMT_INC_TAX'}, {'Source': 'WR_RETURN_QUANTITY', 'Sink': 'WR_RETURN_QUANTITY'}, {'Source': 'WR_RETURN_SHIP_COST', 'Sink': 'WR_RETURN_SHIP_COST'}, {'Source': 'WR_RETURN_TAX', 'Sink': 'WR_RETURN_TAX'}, {'Source': 'WR_REVERSED_CHARGE', 'Sink': 'WR_REVERSED_CHARGE'}, {'Source': 'WR_WEB_PAGE_SK', 'Sink': 'WR_WEB_PAGE_SK'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/WEB_RETURNS', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/WEB_RETURNS'}}]
# [{'ColumnMapping': [{'Source': 'WS_BILL_ADDR_SK', 'Sink': 'WS_BILL_ADDR_SK'}, {'Source': 'WS_BILL_CDEMO_SK', 'Sink': 'WS_BILL_CDEMO_SK'}, {'Source': 'WS_BILL_CUSTOMER_SK', 'Sink': 'WS_BILL_CUSTOMER_SK'}, {'Source': 'WS_BILL_HDEMO_SK', 'Sink': 'WS_BILL_HDEMO_SK'}, {'Source': 'WS_COUPON_AMT', 'Sink': 'WS_COUPON_AMT'}, {'Source': 'WS_EXT_DISCOUNT_AMT', 'Sink': 'WS_EXT_DISCOUNT_AMT'}, {'Source': 'WS_EXT_LIST_PRICE', 'Sink': 'WS_EXT_LIST_PRICE'}, {'Source': 'WS_EXT_SALES_PRICE', 'Sink': 'WS_EXT_SALES_PRICE'}, {'Source': 'WS_EXT_SHIP_COST', 'Sink': 'WS_EXT_SHIP_COST'}, {'Source': 'WS_EXT_TAX', 'Sink': 'WS_EXT_TAX'}, {'Source': 'WS_EXT_WHOLESALE_COST', 'Sink': 'WS_EXT_WHOLESALE_COST'}, {'Source': 'WS_ITEM_SK', 'Sink': 'WS_ITEM_SK'}, {'Source': 'WS_LIST_PRICE', 'Sink': 'WS_LIST_PRICE'}, {'Source': 'WS_NET_PAID', 'Sink': 'WS_NET_PAID'}, {'Source': 'WS_NET_PAID_INC_SHIP', 'Sink': 'WS_NET_PAID_INC_SHIP'}, {'Source': 'WS_NET_PAID_INC_SHIP_TAX', 'Sink': 'WS_NET_PAID_INC_SHIP_TAX'}, {'Source': 'WS_NET_PAID_INC_TAX', 'Sink': 'WS_NET_PAID_INC_TAX'}, {'Source': 'WS_NET_PROFIT', 'Sink': 'WS_NET_PROFIT'}, {'Source': 'WS_ORDER_NUMBER', 'Sink': 'WS_ORDER_NUMBER'}, {'Source': 'WS_PROMO_SK', 'Sink': 'WS_PROMO_SK'}, {'Source': 'WS_QUANTITY', 'Sink': 'WS_QUANTITY'}, {'Source': 'WS_SALES_PRICE', 'Sink': 'WS_SALES_PRICE'}, {'Source': 'WS_SHIP_ADDR_SK', 'Sink': 'WS_SHIP_ADDR_SK'}, {'Source': 'WS_SHIP_CDEMO_SK', 'Sink': 'WS_SHIP_CDEMO_SK'}, {'Source': 'WS_SHIP_CUSTOMER_SK', 'Sink': 'WS_SHIP_CUSTOMER_SK'}, {'Source': 'WS_SHIP_DATE_SK', 'Sink': 'WS_SHIP_DATE_SK'}, {'Source': 'WS_SHIP_HDEMO_SK', 'Sink': 'WS_SHIP_HDEMO_SK'}, {'Source': 'WS_SHIP_MODE_SK', 'Sink': 'WS_SHIP_MODE_SK'}, {'Source': 'WS_SOLD_DATE_SK', 'Sink': 'WS_SOLD_DATE_SK'}, {'Source': 'WS_SOLD_TIME_SK', 'Sink': 'WS_SOLD_TIME_SK'}, {'Source': 'WS_WAREHOUSE_SK', 'Sink': 'WS_WAREHOUSE_SK'}, {'Source': 'WS_WEB_PAGE_SK', 'Sink': 'WS_WEB_PAGE_SK'}, {'Source': 'WS_WEB_SITE_SK', 'Sink': 'WS_WEB_SITE_SK'}, {'Source': 'WS_WHOLESALE_COST', 'Sink': 'WS_WHOLESALE_COST'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/WEB_SALES', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/WEB_SALES'}}]
# [{'ColumnMapping': [{'Source': 'WEB_CITY', 'Sink': 'WEB_CITY'}, {'Source': 'WEB_CLASS', 'Sink': 'WEB_CLASS'}, {'Source': 'WEB_CLOSE_DATE_SK', 'Sink': 'WEB_CLOSE_DATE_SK'}, {'Source': 'WEB_COMPANY_ID', 'Sink': 'WEB_COMPANY_ID'}, {'Source': 'WEB_COMPANY_NAME', 'Sink': 'WEB_COMPANY_NAME'}, {'Source': 'WEB_COUNTRY', 'Sink': 'WEB_COUNTRY'}, {'Source': 'WEB_COUNTY', 'Sink': 'WEB_COUNTY'}, {'Source': 'WEB_GMT_OFFSET', 'Sink': 'WEB_GMT_OFFSET'}, {'Source': 'WEB_MANAGER', 'Sink': 'WEB_MANAGER'}, {'Source': 'WEB_MARKET_MANAGER', 'Sink': 'WEB_MARKET_MANAGER'}, {'Source': 'WEB_MKT_CLASS', 'Sink': 'WEB_MKT_CLASS'}, {'Source': 'WEB_MKT_DESC', 'Sink': 'WEB_MKT_DESC'}, {'Source': 'WEB_MKT_ID', 'Sink': 'WEB_MKT_ID'}, {'Source': 'WEB_NAME', 'Sink': 'WEB_NAME'}, {'Source': 'WEB_OPEN_DATE_SK', 'Sink': 'WEB_OPEN_DATE_SK'}, {'Source': 'WEB_REC_END_DATE', 'Sink': 'WEB_REC_END_DATE'}, {'Source': 'WEB_REC_START_DATE', 'Sink': 'WEB_REC_START_DATE'}, {'Source': 'WEB_SITE_ID', 'Sink': 'WEB_SITE_ID'}, {'Source': 'WEB_SITE_SK', 'Sink': 'WEB_SITE_SK'}, {'Source': 'WEB_STATE', 'Sink': 'WEB_STATE'}, {'Source': 'WEB_STREET_NAME', 'Sink': 'WEB_STREET_NAME'}, {'Source': 'WEB_STREET_NUMBER', 'Sink': 'WEB_STREET_NUMBER'}, {'Source': 'WEB_STREET_TYPE', 'Sink': 'WEB_STREET_TYPE'}, {'Source': 'WEB_SUITE_NUMBER', 'Sink': 'WEB_SUITE_NUMBER'}, {'Source': 'WEB_TAX_PERCENTAGE', 'Sink': 'WEB_TAX_PERCENTAGE'}, {'Source': 'WEB_ZIP', 'Sink': 'WEB_ZIP'}], 'DatasetMapping': {'Source': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF10TCL/tables/WEB_SITE', 'Sink': 'snowflake://https/databases/SNOWFLAKE_SAMPLE_DATA/schemas/TPCDS_SF100TCL/tables/WEB_SITE'}}]
